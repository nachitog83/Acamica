# %% [markdown]
# # Redes Neuronales
#
# En este notebook vamos a construir la unidad básica de las redes neuronales, el Perceptrón. Tiene dos partes:
# 1. **Perceptrón 2D**: vamos a entrenar un Perceptrón con Keras sobre un dataset ficticio. Exploramos cómo son las fronteras en 2D. Limitaciones del Perceptrón. Generamos un dataset no-linealmente separable y vemos cómo responde el Perceptrón.
# 2. **MNIST**: vamos a trabajar con este conocido dataset. El objetivo es identificar dígitos, del 0 al 9, escritos a manos. Primero entrenaremos una red neuronal de una capa y luego una Red Neuronal de más capas.
#
# ## 1. Perceptrón en 2D
#
# Vamos a generar un dataset sintético con unas funciones que ya vienen incorporadas en scikit-learn.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from sklearn.datasets.samples_generator import make_blobs, make_moons

#X, y = make_blobs(n_samples=1000, centers=2, n_features=2,random_state=0)
X, y = make_moons(n_samples=1000, random_state=0)
#X, y = make_circles(n_samples=1000, random_state=0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Reescalamos los datos

# %%
X[:,0] = (X[:,0] - X[:,0].mean())/X[:,0].std()
X[:,1] = (X[:,1] - X[:,1].mean())/X[:,1].std()

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Definimos el modelo a entrenar y volvemos a mirar algunas de sus características.

# %%
model = Sequential()
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs=250, validation_split=0.25)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/250
# 750/750 [==============================] - 1s 2ms/step - loss: 0.5404 - accuracy: 0.8093 - val_loss: 0.5248 - val_accuracy: 0.8280
# Epoch 2/250
# 750/750 [==============================] - 0s 353us/step - loss: 0.5115 - accuracy: 0.8253 - val_loss: 0.4982 - val_accuracy: 0.8480
# Epoch 3/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.4861 - accuracy: 0.8320 - val_loss: 0.4745 - val_accuracy: 0.8520
# Epoch 4/250
# 750/750 [==============================] - 0s 300us/step - loss: 0.4627 - accuracy: 0.8413 - val_loss: 0.4518 - val_accuracy: 0.8560
# Epoch 5/250
# 750/750 [==============================] - 0s 374us/step - loss: 0.4410 - accuracy: 0.8453 - val_loss: 0.4304 - val_accuracy: 0.8520
# Epoch 6/250
# 750/750 [==============================] - 0s 365us/step - loss: 0.4212 - accuracy: 0.8493 - val_loss: 0.4118 - val_accuracy: 0.8560
# Epoch 7/250
# 750/750 [==============================] - 0s 386us/step - loss: 0.4043 - accuracy: 0.8493 - val_loss: 0.3948 - val_accuracy: 0.8560
# Epoch 8/250
# 750/750 [==============================] - 0s 396us/step - loss: 0.3886 - accuracy: 0.8507 - val_loss: 0.3798 - val_accuracy: 0.8520
# Epoch 9/250
# 750/750 [==============================] - 0s 325us/step - loss: 0.3747 - accuracy: 0.8547 - val_loss: 0.3649 - val_accuracy: 0.8560
# Epoch 10/250
# 750/750 [==============================] - 0s 335us/step - loss: 0.3620 - accuracy: 0.8573 - val_loss: 0.3517 - val_accuracy: 0.8560
# Epoch 11/250
# 750/750 [==============================] - 0s 305us/step - loss: 0.3503 - accuracy: 0.8600 - val_loss: 0.3394 - val_accuracy: 0.8560
# Epoch 12/250
# 750/750 [==============================] - 0s 393us/step - loss: 0.3399 - accuracy: 0.8640 - val_loss: 0.3288 - val_accuracy: 0.8560
# Epoch 13/250
# 750/750 [==============================] - 0s 255us/step - loss: 0.3303 - accuracy: 0.8667 - val_loss: 0.3184 - val_accuracy: 0.8600
# Epoch 14/250
# 750/750 [==============================] - 0s 331us/step - loss: 0.3219 - accuracy: 0.8680 - val_loss: 0.3101 - val_accuracy: 0.8600
# Epoch 15/250
# 750/750 [==============================] - 0s 379us/step - loss: 0.3149 - accuracy: 0.8680 - val_loss: 0.3020 - val_accuracy: 0.8680
# Epoch 16/250
# 750/750 [==============================] - 0s 441us/step - loss: 0.3082 - accuracy: 0.8680 - val_loss: 0.2949 - val_accuracy: 0.8680
# Epoch 17/250
# 750/750 [==============================] - 0s 420us/step - loss: 0.3019 - accuracy: 0.8720 - val_loss: 0.2878 - val_accuracy: 0.8720
# Epoch 18/250
# 750/750 [==============================] - 0s 366us/step - loss: 0.2970 - accuracy: 0.8720 - val_loss: 0.2829 - val_accuracy: 0.8800
# Epoch 19/250
# 750/750 [==============================] - 0s 381us/step - loss: 0.2927 - accuracy: 0.8720 - val_loss: 0.2770 - val_accuracy: 0.8800
# Epoch 20/250
# 750/750 [==============================] - 0s 348us/step - loss: 0.2882 - accuracy: 0.8733 - val_loss: 0.2719 - val_accuracy: 0.8840
# Epoch 21/250
# 750/750 [==============================] - 0s 356us/step - loss: 0.2836 - accuracy: 0.8747 - val_loss: 0.2667 - val_accuracy: 0.8920
# Epoch 22/250
# 750/750 [==============================] - 0s 325us/step - loss: 0.2799 - accuracy: 0.8747 - val_loss: 0.2622 - val_accuracy: 0.8960
# Epoch 23/250
# 750/750 [==============================] - 0s 362us/step - loss: 0.2768 - accuracy: 0.8760 - val_loss: 0.2586 - val_accuracy: 0.8960
# Epoch 24/250
# 750/750 [==============================] - 0s 371us/step - loss: 0.2738 - accuracy: 0.8773 - val_loss: 0.2549 - val_accuracy: 0.8960
# Epoch 25/250
# 750/750 [==============================] - 0s 343us/step - loss: 0.2708 - accuracy: 0.8800 - val_loss: 0.2516 - val_accuracy: 0.8960
# Epoch 26/250
# 750/750 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.88 - 0s 261us/step - loss: 0.2677 - accuracy: 0.8813 - val_loss: 0.2484 - val_accuracy: 0.8960
# Epoch 27/250
# 750/750 [==============================] - 0s 228us/step - loss: 0.2650 - accuracy: 0.8840 - val_loss: 0.2446 - val_accuracy: 0.8960
# Epoch 28/250
# 750/750 [==============================] - 0s 281us/step - loss: 0.2624 - accuracy: 0.8840 - val_loss: 0.2415 - val_accuracy: 0.9000
# Epoch 29/250
# 750/750 [==============================] - 0s 347us/step - loss: 0.2601 - accuracy: 0.8840 - val_loss: 0.2388 - val_accuracy: 0.9040
# Epoch 30/250
# 750/750 [==============================] - 0s 321us/step - loss: 0.2576 - accuracy: 0.8840 - val_loss: 0.2363 - val_accuracy: 0.9080
# Epoch 31/250
# 750/750 [==============================] - 0s 258us/step - loss: 0.2556 - accuracy: 0.8853 - val_loss: 0.2340 - val_accuracy: 0.9080
# Epoch 32/250
# 750/750 [==============================] - 0s 370us/step - loss: 0.2537 - accuracy: 0.8867 - val_loss: 0.2321 - val_accuracy: 0.9080
# Epoch 33/250
# 750/750 [==============================] - 0s 293us/step - loss: 0.2514 - accuracy: 0.8867 - val_loss: 0.2294 - val_accuracy: 0.9080
# Epoch 34/250
# 750/750 [==============================] - 0s 354us/step - loss: 0.2494 - accuracy: 0.8893 - val_loss: 0.2276 - val_accuracy: 0.9080
# Epoch 35/250
# 750/750 [==============================] - 0s 314us/step - loss: 0.2475 - accuracy: 0.8893 - val_loss: 0.2252 - val_accuracy: 0.9080
# Epoch 36/250
# 750/750 [==============================] - 0s 395us/step - loss: 0.2457 - accuracy: 0.8907 - val_loss: 0.2234 - val_accuracy: 0.9080
# Epoch 37/250
# 750/750 [==============================] - 0s 367us/step - loss: 0.2441 - accuracy: 0.8920 - val_loss: 0.2219 - val_accuracy: 0.9080
# Epoch 38/250
# 750/750 [==============================] - 0s 262us/step - loss: 0.2426 - accuracy: 0.8933 - val_loss: 0.2202 - val_accuracy: 0.9080
# Epoch 39/250
# 750/750 [==============================] - 0s 296us/step - loss: 0.2409 - accuracy: 0.8933 - val_loss: 0.2182 - val_accuracy: 0.9080
# Epoch 40/250
# 750/750 [==============================] - 0s 258us/step - loss: 0.2393 - accuracy: 0.8947 - val_loss: 0.2167 - val_accuracy: 0.9080
# Epoch 41/250
# 750/750 [==============================] - 0s 329us/step - loss: 0.2377 - accuracy: 0.8947 - val_loss: 0.2152 - val_accuracy: 0.9080
# Epoch 42/250
# 750/750 [==============================] - 0s 378us/step - loss: 0.2362 - accuracy: 0.8947 - val_loss: 0.2137 - val_accuracy: 0.9080
# Epoch 43/250
# 750/750 [==============================] - 0s 364us/step - loss: 0.2346 - accuracy: 0.8947 - val_loss: 0.2121 - val_accuracy: 0.9080
# Epoch 44/250
# 750/750 [==============================] - 0s 320us/step - loss: 0.2334 - accuracy: 0.8933 - val_loss: 0.2108 - val_accuracy: 0.9080
# Epoch 45/250
# 750/750 [==============================] - 0s 319us/step - loss: 0.2323 - accuracy: 0.8933 - val_loss: 0.2094 - val_accuracy: 0.9120
# Epoch 46/250
# 750/750 [==============================] - 0s 309us/step - loss: 0.2307 - accuracy: 0.8920 - val_loss: 0.2080 - val_accuracy: 0.9120
# Epoch 47/250
# 750/750 [==============================] - 0s 296us/step - loss: 0.2293 - accuracy: 0.8907 - val_loss: 0.2070 - val_accuracy: 0.9120
# Epoch 48/250
# 750/750 [==============================] - 0s 336us/step - loss: 0.2280 - accuracy: 0.8947 - val_loss: 0.2061 - val_accuracy: 0.9120
# Epoch 49/250
# 750/750 [==============================] - 0s 403us/step - loss: 0.2267 - accuracy: 0.8947 - val_loss: 0.2051 - val_accuracy: 0.9120
# Epoch 50/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.2256 - accuracy: 0.8960 - val_loss: 0.2040 - val_accuracy: 0.9120
# Epoch 51/250
# 750/750 [==============================] - 0s 298us/step - loss: 0.2246 - accuracy: 0.8973 - val_loss: 0.2035 - val_accuracy: 0.9120
# Epoch 52/250
# 750/750 [==============================] - 0s 351us/step - loss: 0.2234 - accuracy: 0.8960 - val_loss: 0.2026 - val_accuracy: 0.9120
# Epoch 53/250
# 750/750 [==============================] - 0s 286us/step - loss: 0.2224 - accuracy: 0.8960 - val_loss: 0.2009 - val_accuracy: 0.9080
# Epoch 54/250
# 750/750 [==============================] - 0s 329us/step - loss: 0.2214 - accuracy: 0.8973 - val_loss: 0.2000 - val_accuracy: 0.9080
# Epoch 55/250
# 750/750 [==============================] - 0s 276us/step - loss: 0.2202 - accuracy: 0.8973 - val_loss: 0.1993 - val_accuracy: 0.9080
# Epoch 56/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.2194 - accuracy: 0.8987 - val_loss: 0.1986 - val_accuracy: 0.9080
# Epoch 57/250
# 750/750 [==============================] - 0s 272us/step - loss: 0.2185 - accuracy: 0.9000 - val_loss: 0.1981 - val_accuracy: 0.9080
# Epoch 58/250
# 750/750 [==============================] - 0s 377us/step - loss: 0.2176 - accuracy: 0.9013 - val_loss: 0.1971 - val_accuracy: 0.9080
# Epoch 59/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.2168 - accuracy: 0.8987 - val_loss: 0.1964 - val_accuracy: 0.9080
# Epoch 60/250
# 750/750 [==============================] - 0s 339us/step - loss: 0.2159 - accuracy: 0.9000 - val_loss: 0.1955 - val_accuracy: 0.9080
# Epoch 61/250
# 750/750 [==============================] - 0s 250us/step - loss: 0.2149 - accuracy: 0.9000 - val_loss: 0.1949 - val_accuracy: 0.9080
# Epoch 62/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.2140 - accuracy: 0.9013 - val_loss: 0.1947 - val_accuracy: 0.9080
# Epoch 63/250
# 750/750 [==============================] - 0s 302us/step - loss: 0.2134 - accuracy: 0.9013 - val_loss: 0.1936 - val_accuracy: 0.9080
# Epoch 64/250
# 750/750 [==============================] - 0s 234us/step - loss: 0.2127 - accuracy: 0.9013 - val_loss: 0.1934 - val_accuracy: 0.9120
# Epoch 65/250
# 750/750 [==============================] - 0s 303us/step - loss: 0.2120 - accuracy: 0.9013 - val_loss: 0.1927 - val_accuracy: 0.9120
# Epoch 66/250
# 750/750 [==============================] - 0s 311us/step - loss: 0.2114 - accuracy: 0.9027 - val_loss: 0.1919 - val_accuracy: 0.9120
# Epoch 67/250
# 750/750 [==============================] - 0s 348us/step - loss: 0.2106 - accuracy: 0.9013 - val_loss: 0.1912 - val_accuracy: 0.9120
# Epoch 68/250
# 750/750 [==============================] - 0s 339us/step - loss: 0.2099 - accuracy: 0.9027 - val_loss: 0.1909 - val_accuracy: 0.9120
# Epoch 69/250
# 750/750 [==============================] - 0s 317us/step - loss: 0.2092 - accuracy: 0.9013 - val_loss: 0.1905 - val_accuracy: 0.9120
# Epoch 70/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.2087 - accuracy: 0.9013 - val_loss: 0.1898 - val_accuracy: 0.9120
# Epoch 71/250
# 750/750 [==============================] - 0s 227us/step - loss: 0.2078 - accuracy: 0.9027 - val_loss: 0.1890 - val_accuracy: 0.9120
# Epoch 72/250
# 750/750 [==============================] - 0s 251us/step - loss: 0.2071 - accuracy: 0.9027 - val_loss: 0.1885 - val_accuracy: 0.9120
# Epoch 73/250
# 750/750 [==============================] - 0s 385us/step - loss: 0.2063 - accuracy: 0.9040 - val_loss: 0.1881 - val_accuracy: 0.9160
# Epoch 74/250
# 750/750 [==============================] - 0s 279us/step - loss: 0.2055 - accuracy: 0.9040 - val_loss: 0.1875 - val_accuracy: 0.9160
# Epoch 75/250
# 750/750 [==============================] - 0s 280us/step - loss: 0.2049 - accuracy: 0.9027 - val_loss: 0.1870 - val_accuracy: 0.9160
# Epoch 76/250
# 750/750 [==============================] - 0s 274us/step - loss: 0.2044 - accuracy: 0.9040 - val_loss: 0.1866 - val_accuracy: 0.9160
# Epoch 77/250
# 750/750 [==============================] - 0s 274us/step - loss: 0.2036 - accuracy: 0.9053 - val_loss: 0.1858 - val_accuracy: 0.9160
# Epoch 78/250
# 750/750 [==============================] - 0s 555us/step - loss: 0.2030 - accuracy: 0.9067 - val_loss: 0.1850 - val_accuracy: 0.9160
# Epoch 79/250
# 750/750 [==============================] - 0s 400us/step - loss: 0.2026 - accuracy: 0.9040 - val_loss: 0.1840 - val_accuracy: 0.9160
# Epoch 80/250
# 750/750 [==============================] - 0s 493us/step - loss: 0.2017 - accuracy: 0.9067 - val_loss: 0.1842 - val_accuracy: 0.9160
# Epoch 81/250
# 750/750 [==============================] - 0s 375us/step - loss: 0.2014 - accuracy: 0.9053 - val_loss: 0.1835 - val_accuracy: 0.9160
# Epoch 82/250
# 750/750 [==============================] - 0s 320us/step - loss: 0.2009 - accuracy: 0.9067 - val_loss: 0.1829 - val_accuracy: 0.9160
# Epoch 83/250
# 750/750 [==============================] - 0s 216us/step - loss: 0.2002 - accuracy: 0.9067 - val_loss: 0.1822 - val_accuracy: 0.9160
# Epoch 84/250
# 750/750 [==============================] - 0s 355us/step - loss: 0.2000 - accuracy: 0.9080 - val_loss: 0.1819 - val_accuracy: 0.9160
# Epoch 85/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.1993 - accuracy: 0.9080 - val_loss: 0.1812 - val_accuracy: 0.9160
# Epoch 86/250
# 750/750 [==============================] - 0s 293us/step - loss: 0.1989 - accuracy: 0.9080 - val_loss: 0.1810 - val_accuracy: 0.9160
# Epoch 87/250
# 750/750 [==============================] - 0s 285us/step - loss: 0.1984 - accuracy: 0.9107 - val_loss: 0.1808 - val_accuracy: 0.9160
# Epoch 88/250
# 750/750 [==============================] - 0s 295us/step - loss: 0.1977 - accuracy: 0.9093 - val_loss: 0.1800 - val_accuracy: 0.9160
# Epoch 89/250
# 750/750 [==============================] - 0s 339us/step - loss: 0.1974 - accuracy: 0.9093 - val_loss: 0.1795 - val_accuracy: 0.9160
# Epoch 90/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.1971 - accuracy: 0.9093 - val_loss: 0.1794 - val_accuracy: 0.9160
# Epoch 91/250
# 750/750 [==============================] - 0s 242us/step - loss: 0.1964 - accuracy: 0.9107 - val_loss: 0.1785 - val_accuracy: 0.9160
# Epoch 92/250
# 750/750 [==============================] - 0s 281us/step - loss: 0.1960 - accuracy: 0.9107 - val_loss: 0.1786 - val_accuracy: 0.9160
# Epoch 93/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.1956 - accuracy: 0.9093 - val_loss: 0.1782 - val_accuracy: 0.9160
# Epoch 94/250
# 750/750 [==============================] - 0s 239us/step - loss: 0.1952 - accuracy: 0.9093 - val_loss: 0.1778 - val_accuracy: 0.9160
# Epoch 95/250
# 750/750 [==============================] - 0s 307us/step - loss: 0.1947 - accuracy: 0.9093 - val_loss: 0.1774 - val_accuracy: 0.9160
# Epoch 96/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.1939 - accuracy: 0.9107 - val_loss: 0.1771 - val_accuracy: 0.9160
# Epoch 97/250
# 750/750 [==============================] - 0s 290us/step - loss: 0.1936 - accuracy: 0.9120 - val_loss: 0.1765 - val_accuracy: 0.9160
# Epoch 98/250
# 750/750 [==============================] - 0s 256us/step - loss: 0.1931 - accuracy: 0.9133 - val_loss: 0.1767 - val_accuracy: 0.9160
# Epoch 99/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.1926 - accuracy: 0.9133 - val_loss: 0.1764 - val_accuracy: 0.9160
# Epoch 100/250
# 750/750 [==============================] - 0s 323us/step - loss: 0.1922 - accuracy: 0.9147 - val_loss: 0.1759 - val_accuracy: 0.9160
# Epoch 101/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.1916 - accuracy: 0.9133 - val_loss: 0.1755 - val_accuracy: 0.9160
# Epoch 102/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.1911 - accuracy: 0.9133 - val_loss: 0.1751 - val_accuracy: 0.9160
# Epoch 103/250
# 750/750 [==============================] - 0s 340us/step - loss: 0.1906 - accuracy: 0.9147 - val_loss: 0.1748 - val_accuracy: 0.9160
# Epoch 104/250
# 750/750 [==============================] - 0s 317us/step - loss: 0.1902 - accuracy: 0.9133 - val_loss: 0.1744 - val_accuracy: 0.9200
# Epoch 105/250
# 750/750 [==============================] - 0s 412us/step - loss: 0.1897 - accuracy: 0.9147 - val_loss: 0.1741 - val_accuracy: 0.9200
# Epoch 106/250
# 750/750 [==============================] - 0s 343us/step - loss: 0.1891 - accuracy: 0.9147 - val_loss: 0.1742 - val_accuracy: 0.9200
# Epoch 107/250
# 750/750 [==============================] - 0s 348us/step - loss: 0.1888 - accuracy: 0.9160 - val_loss: 0.1739 - val_accuracy: 0.9200
# Epoch 108/250
# 750/750 [==============================] - 0s 305us/step - loss: 0.1888 - accuracy: 0.9147 - val_loss: 0.1734 - val_accuracy: 0.9200
# Epoch 109/250
# 750/750 [==============================] - 0s 267us/step - loss: 0.1881 - accuracy: 0.9147 - val_loss: 0.1731 - val_accuracy: 0.9200
# Epoch 110/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.1875 - accuracy: 0.9160 - val_loss: 0.1724 - val_accuracy: 0.9200
# Epoch 111/250
# 750/750 [==============================] - 0s 287us/step - loss: 0.1875 - accuracy: 0.9160 - val_loss: 0.1722 - val_accuracy: 0.9200
# Epoch 112/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.1870 - accuracy: 0.9173 - val_loss: 0.1717 - val_accuracy: 0.9200
# Epoch 113/250
# 750/750 [==============================] - 0s 337us/step - loss: 0.1864 - accuracy: 0.9173 - val_loss: 0.1710 - val_accuracy: 0.9200
# Epoch 114/250
# 750/750 [==============================] - 0s 251us/step - loss: 0.1859 - accuracy: 0.9173 - val_loss: 0.1705 - val_accuracy: 0.9240
# Epoch 115/250
# 750/750 [==============================] - 0s 450us/step - loss: 0.1857 - accuracy: 0.9160 - val_loss: 0.1700 - val_accuracy: 0.9240
# Epoch 116/250
# 750/750 [==============================] - 0s 247us/step - loss: 0.1852 - accuracy: 0.9187 - val_loss: 0.1698 - val_accuracy: 0.9240
# Epoch 117/250
# 750/750 [==============================] - 0s 263us/step - loss: 0.1846 - accuracy: 0.9173 - val_loss: 0.1691 - val_accuracy: 0.9240
# Epoch 118/250
# 750/750 [==============================] - 0s 281us/step - loss: 0.1841 - accuracy: 0.9187 - val_loss: 0.1685 - val_accuracy: 0.9240
# Epoch 119/250
# 750/750 [==============================] - 0s 300us/step - loss: 0.1842 - accuracy: 0.9173 - val_loss: 0.1683 - val_accuracy: 0.9240
# Epoch 120/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.1839 - accuracy: 0.9173 - val_loss: 0.1686 - val_accuracy: 0.9240
# Epoch 121/250
# 750/750 [==============================] - 0s 290us/step - loss: 0.1837 - accuracy: 0.9187 - val_loss: 0.1683 - val_accuracy: 0.9240
# Epoch 122/250
# 750/750 [==============================] - 0s 280us/step - loss: 0.1828 - accuracy: 0.9200 - val_loss: 0.1675 - val_accuracy: 0.9280
# Epoch 123/250
# 750/750 [==============================] - 0s 272us/step - loss: 0.1831 - accuracy: 0.9187 - val_loss: 0.1669 - val_accuracy: 0.9280
# Epoch 124/250
# 750/750 [==============================] - 0s 275us/step - loss: 0.1826 - accuracy: 0.9173 - val_loss: 0.1671 - val_accuracy: 0.9280
# Epoch 125/250
# 750/750 [==============================] - 0s 259us/step - loss: 0.1826 - accuracy: 0.9173 - val_loss: 0.1667 - val_accuracy: 0.9280
# Epoch 126/250
# 750/750 [==============================] - 0s 223us/step - loss: 0.1822 - accuracy: 0.9187 - val_loss: 0.1665 - val_accuracy: 0.9280
# Epoch 127/250
# 750/750 [==============================] - 0s 229us/step - loss: 0.1818 - accuracy: 0.9187 - val_loss: 0.1661 - val_accuracy: 0.9280
# Epoch 128/250
# 750/750 [==============================] - 0s 319us/step - loss: 0.1818 - accuracy: 0.9200 - val_loss: 0.1654 - val_accuracy: 0.9280
# Epoch 129/250
# 750/750 [==============================] - 0s 303us/step - loss: 0.1813 - accuracy: 0.9213 - val_loss: 0.1655 - val_accuracy: 0.9280
# Epoch 130/250
# 750/750 [==============================] - 0s 290us/step - loss: 0.1806 - accuracy: 0.9227 - val_loss: 0.1654 - val_accuracy: 0.9280
# Epoch 131/250
# 750/750 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.92 - 0s 265us/step - loss: 0.1805 - accuracy: 0.9227 - val_loss: 0.1648 - val_accuracy: 0.9280
# Epoch 132/250
# 750/750 [==============================] - 0s 337us/step - loss: 0.1800 - accuracy: 0.9227 - val_loss: 0.1643 - val_accuracy: 0.9280
# Epoch 133/250
# 750/750 [==============================] - 0s 287us/step - loss: 0.1799 - accuracy: 0.9227 - val_loss: 0.1643 - val_accuracy: 0.9280
# Epoch 134/250
# 750/750 [==============================] - 0s 279us/step - loss: 0.1798 - accuracy: 0.9213 - val_loss: 0.1639 - val_accuracy: 0.9280
# Epoch 135/250
# 750/750 [==============================] - 0s 251us/step - loss: 0.1792 - accuracy: 0.9240 - val_loss: 0.1633 - val_accuracy: 0.9320
# Epoch 136/250
# 750/750 [==============================] - 0s 254us/step - loss: 0.1791 - accuracy: 0.9227 - val_loss: 0.1625 - val_accuracy: 0.9320
# Epoch 137/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.1787 - accuracy: 0.9227 - val_loss: 0.1622 - val_accuracy: 0.9360
# Epoch 138/250
# 750/750 [==============================] - 0s 297us/step - loss: 0.1781 - accuracy: 0.9227 - val_loss: 0.1623 - val_accuracy: 0.9320
# Epoch 139/250
# 750/750 [==============================] - 0s 342us/step - loss: 0.1779 - accuracy: 0.9227 - val_loss: 0.1615 - val_accuracy: 0.9400
# Epoch 140/250
# 750/750 [==============================] - 0s 232us/step - loss: 0.1779 - accuracy: 0.9213 - val_loss: 0.1608 - val_accuracy: 0.9400
# Epoch 141/250
# 750/750 [==============================] - 0s 276us/step - loss: 0.1774 - accuracy: 0.9227 - val_loss: 0.1613 - val_accuracy: 0.9360
# Epoch 142/250
# 750/750 [==============================] - 0s 384us/step - loss: 0.1774 - accuracy: 0.9227 - val_loss: 0.1608 - val_accuracy: 0.9400
# Epoch 143/250
# 750/750 [==============================] - 0s 297us/step - loss: 0.1768 - accuracy: 0.9240 - val_loss: 0.1605 - val_accuracy: 0.9400
# Epoch 144/250
# 750/750 [==============================] - 0s 320us/step - loss: 0.1765 - accuracy: 0.9227 - val_loss: 0.1605 - val_accuracy: 0.9400
# Epoch 145/250
# 750/750 [==============================] - 0s 286us/step - loss: 0.1768 - accuracy: 0.9227 - val_loss: 0.1599 - val_accuracy: 0.9400
# Epoch 146/250
# 750/750 [==============================] - 0s 290us/step - loss: 0.1768 - accuracy: 0.9213 - val_loss: 0.1591 - val_accuracy: 0.9400
# Epoch 147/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.1766 - accuracy: 0.9227 - val_loss: 0.1588 - val_accuracy: 0.9400
# Epoch 148/250
# 750/750 [==============================] - 0s 237us/step - loss: 0.1764 - accuracy: 0.9227 - val_loss: 0.1583 - val_accuracy: 0.9400
# Epoch 149/250
# 750/750 [==============================] - 0s 282us/step - loss: 0.1757 - accuracy: 0.9253 - val_loss: 0.1578 - val_accuracy: 0.9400
# Epoch 150/250
# 750/750 [==============================] - 0s 268us/step - loss: 0.1759 - accuracy: 0.9240 - val_loss: 0.1578 - val_accuracy: 0.9400
# Epoch 151/250
# 750/750 [==============================] - 0s 241us/step - loss: 0.1758 - accuracy: 0.9240 - val_loss: 0.1575 - val_accuracy: 0.9400
# Epoch 152/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.1757 - accuracy: 0.9240 - val_loss: 0.1573 - val_accuracy: 0.9400
# Epoch 153/250
# 750/750 [==============================] - 0s 259us/step - loss: 0.1754 - accuracy: 0.9267 - val_loss: 0.1571 - val_accuracy: 0.9400
# Epoch 154/250
# 750/750 [==============================] - 0s 375us/step - loss: 0.1749 - accuracy: 0.9267 - val_loss: 0.1570 - val_accuracy: 0.9400
# Epoch 155/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.1749 - accuracy: 0.9267 - val_loss: 0.1567 - val_accuracy: 0.9400
# Epoch 156/250
# 750/750 [==============================] - 0s 289us/step - loss: 0.1740 - accuracy: 0.9267 - val_loss: 0.1566 - val_accuracy: 0.9400
# Epoch 157/250
# 750/750 [==============================] - 0s 276us/step - loss: 0.1737 - accuracy: 0.9293 - val_loss: 0.1564 - val_accuracy: 0.9400
# Epoch 158/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.1734 - accuracy: 0.9280 - val_loss: 0.1569 - val_accuracy: 0.9400
# Epoch 159/250
# 750/750 [==============================] - 0s 269us/step - loss: 0.1733 - accuracy: 0.9307 - val_loss: 0.1571 - val_accuracy: 0.9400
# Epoch 160/250
# 750/750 [==============================] - 0s 342us/step - loss: 0.1731 - accuracy: 0.9307 - val_loss: 0.1563 - val_accuracy: 0.9400
# Epoch 161/250
# 750/750 [==============================] - 0s 304us/step - loss: 0.1727 - accuracy: 0.9293 - val_loss: 0.1561 - val_accuracy: 0.9400
# Epoch 162/250
# 750/750 [==============================] - 0s 235us/step - loss: 0.1730 - accuracy: 0.9307 - val_loss: 0.1560 - val_accuracy: 0.9400
# Epoch 163/250
# 750/750 [==============================] - 0s 293us/step - loss: 0.1722 - accuracy: 0.9293 - val_loss: 0.1556 - val_accuracy: 0.9400
# Epoch 164/250
# 750/750 [==============================] - 0s 266us/step - loss: 0.1725 - accuracy: 0.9293 - val_loss: 0.1557 - val_accuracy: 0.9400
# Epoch 165/250
# 750/750 [==============================] - 0s 294us/step - loss: 0.1721 - accuracy: 0.9293 - val_loss: 0.1550 - val_accuracy: 0.9400
# Epoch 166/250
# 750/750 [==============================] - 0s 326us/step - loss: 0.1722 - accuracy: 0.9293 - val_loss: 0.1547 - val_accuracy: 0.9400
# Epoch 167/250
# 750/750 [==============================] - 0s 347us/step - loss: 0.1722 - accuracy: 0.9267 - val_loss: 0.1548 - val_accuracy: 0.9400
# Epoch 168/250
# 750/750 [==============================] - 0s 322us/step - loss: 0.1718 - accuracy: 0.9293 - val_loss: 0.1544 - val_accuracy: 0.9400
# Epoch 169/250
# 750/750 [==============================] - 0s 280us/step - loss: 0.1712 - accuracy: 0.9307 - val_loss: 0.1539 - val_accuracy: 0.9400
# Epoch 170/250
# 750/750 [==============================] - 0s 381us/step - loss: 0.1709 - accuracy: 0.9307 - val_loss: 0.1539 - val_accuracy: 0.9400
# Epoch 171/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.1708 - accuracy: 0.9307 - val_loss: 0.1532 - val_accuracy: 0.9400
# Epoch 172/250
# 750/750 [==============================] - 0s 352us/step - loss: 0.1698 - accuracy: 0.9320 - val_loss: 0.1535 - val_accuracy: 0.9400
# Epoch 173/250
# 750/750 [==============================] - 0s 339us/step - loss: 0.1704 - accuracy: 0.9320 - val_loss: 0.1522 - val_accuracy: 0.9400
# Epoch 174/250
# 750/750 [==============================] - 0s 252us/step - loss: 0.1704 - accuracy: 0.9320 - val_loss: 0.1523 - val_accuracy: 0.9400
# Epoch 175/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.1699 - accuracy: 0.9320 - val_loss: 0.1522 - val_accuracy: 0.9400
# Epoch 176/250
# 750/750 [==============================] - 0s 305us/step - loss: 0.1697 - accuracy: 0.9320 - val_loss: 0.1516 - val_accuracy: 0.9400
# Epoch 177/250
# 750/750 [==============================] - 0s 295us/step - loss: 0.1694 - accuracy: 0.9320 - val_loss: 0.1515 - val_accuracy: 0.9440
# Epoch 178/250
# 750/750 [==============================] - 0s 285us/step - loss: 0.1691 - accuracy: 0.9320 - val_loss: 0.1515 - val_accuracy: 0.9400
# Epoch 179/250
# 750/750 [==============================] - 0s 351us/step - loss: 0.1690 - accuracy: 0.9320 - val_loss: 0.1510 - val_accuracy: 0.9400
# Epoch 180/250
# 750/750 [==============================] - 0s 242us/step - loss: 0.1685 - accuracy: 0.9320 - val_loss: 0.1517 - val_accuracy: 0.9400
# Epoch 181/250
# 750/750 [==============================] - 0s 257us/step - loss: 0.1688 - accuracy: 0.9320 - val_loss: 0.1509 - val_accuracy: 0.9400
# Epoch 182/250
# 750/750 [==============================] - 0s 305us/step - loss: 0.1677 - accuracy: 0.9347 - val_loss: 0.1497 - val_accuracy: 0.9440
# Epoch 183/250
# 750/750 [==============================] - 0s 340us/step - loss: 0.1678 - accuracy: 0.9320 - val_loss: 0.1494 - val_accuracy: 0.9440
# Epoch 184/250
# 750/750 [==============================] - 0s 254us/step - loss: 0.1674 - accuracy: 0.9333 - val_loss: 0.1502 - val_accuracy: 0.9440
# Epoch 185/250
# 750/750 [==============================] - 0s 265us/step - loss: 0.1676 - accuracy: 0.9347 - val_loss: 0.1496 - val_accuracy: 0.9440
# Epoch 186/250
# 750/750 [==============================] - 0s 340us/step - loss: 0.1674 - accuracy: 0.9347 - val_loss: 0.1491 - val_accuracy: 0.9440
# Epoch 187/250
# 750/750 [==============================] - 0s 330us/step - loss: 0.1672 - accuracy: 0.9347 - val_loss: 0.1492 - val_accuracy: 0.9440
# Epoch 188/250
# 750/750 [==============================] - 0s 238us/step - loss: 0.1673 - accuracy: 0.9333 - val_loss: 0.1485 - val_accuracy: 0.9440
# Epoch 189/250
# 750/750 [==============================] - 0s 254us/step - loss: 0.1673 - accuracy: 0.9333 - val_loss: 0.1479 - val_accuracy: 0.9440
# Epoch 190/250
# 750/750 [==============================] - 0s 282us/step - loss: 0.1671 - accuracy: 0.9333 - val_loss: 0.1480 - val_accuracy: 0.9440
# Epoch 191/250
# 750/750 [==============================] - 0s 320us/step - loss: 0.1662 - accuracy: 0.9333 - val_loss: 0.1484 - val_accuracy: 0.9440
# Epoch 192/250
# 750/750 [==============================] - 0s 328us/step - loss: 0.1658 - accuracy: 0.9347 - val_loss: 0.1480 - val_accuracy: 0.9440
# Epoch 193/250
# 750/750 [==============================] - 0s 324us/step - loss: 0.1653 - accuracy: 0.9347 - val_loss: 0.1473 - val_accuracy: 0.9440
# Epoch 194/250
# 750/750 [==============================] - 0s 371us/step - loss: 0.1640 - accuracy: 0.9373 - val_loss: 0.1467 - val_accuracy: 0.9440
# Epoch 195/250
# 750/750 [==============================] - 0s 347us/step - loss: 0.1635 - accuracy: 0.9360 - val_loss: 0.1461 - val_accuracy: 0.9440
# Epoch 196/250
# 750/750 [==============================] - 0s 288us/step - loss: 0.1627 - accuracy: 0.9373 - val_loss: 0.1454 - val_accuracy: 0.9440
# Epoch 197/250
# 750/750 [==============================] - 0s 259us/step - loss: 0.1626 - accuracy: 0.9373 - val_loss: 0.1453 - val_accuracy: 0.9440
# Epoch 198/250
# 750/750 [==============================] - 0s 351us/step - loss: 0.1624 - accuracy: 0.9373 - val_loss: 0.1449 - val_accuracy: 0.9440
# Epoch 199/250
# 750/750 [==============================] - 0s 295us/step - loss: 0.1625 - accuracy: 0.9373 - val_loss: 0.1443 - val_accuracy: 0.9440
# Epoch 200/250
# 750/750 [==============================] - 0s 294us/step - loss: 0.1623 - accuracy: 0.9387 - val_loss: 0.1441 - val_accuracy: 0.9440
# Epoch 201/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.1616 - accuracy: 0.9400 - val_loss: 0.1437 - val_accuracy: 0.9440
# Epoch 202/250
# 750/750 [==============================] - 0s 274us/step - loss: 0.1612 - accuracy: 0.9400 - val_loss: 0.1431 - val_accuracy: 0.9440
# Epoch 203/250
# 750/750 [==============================] - 0s 237us/step - loss: 0.1607 - accuracy: 0.9387 - val_loss: 0.1429 - val_accuracy: 0.9440
# Epoch 204/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.1602 - accuracy: 0.9387 - val_loss: 0.1426 - val_accuracy: 0.9440
# Epoch 205/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.1594 - accuracy: 0.9400 - val_loss: 0.1421 - val_accuracy: 0.9440
# Epoch 206/250
# 750/750 [==============================] - 0s 245us/step - loss: 0.1603 - accuracy: 0.9387 - val_loss: 0.1416 - val_accuracy: 0.9440
# Epoch 207/250
# 750/750 [==============================] - 0s 285us/step - loss: 0.1596 - accuracy: 0.9400 - val_loss: 0.1409 - val_accuracy: 0.9440
# Epoch 208/250
# 750/750 [==============================] - 0s 260us/step - loss: 0.1594 - accuracy: 0.9400 - val_loss: 0.1407 - val_accuracy: 0.9440
# Epoch 209/250
# 750/750 [==============================] - 0s 344us/step - loss: 0.1594 - accuracy: 0.9413 - val_loss: 0.1403 - val_accuracy: 0.9440
# Epoch 210/250
# 750/750 [==============================] - 0s 251us/step - loss: 0.1600 - accuracy: 0.9400 - val_loss: 0.1400 - val_accuracy: 0.9440
# Epoch 211/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.1591 - accuracy: 0.9400 - val_loss: 0.1401 - val_accuracy: 0.9440
# Epoch 212/250
# 750/750 [==============================] - 0s 316us/step - loss: 0.1587 - accuracy: 0.9427 - val_loss: 0.1403 - val_accuracy: 0.9440
# Epoch 213/250
# 750/750 [==============================] - 0s 286us/step - loss: 0.1584 - accuracy: 0.9400 - val_loss: 0.1408 - val_accuracy: 0.9440
# Epoch 214/250
# 750/750 [==============================] - 0s 274us/step - loss: 0.1584 - accuracy: 0.9413 - val_loss: 0.1400 - val_accuracy: 0.9440
# Epoch 215/250
# 750/750 [==============================] - 0s 267us/step - loss: 0.1580 - accuracy: 0.9413 - val_loss: 0.1394 - val_accuracy: 0.9440
# Epoch 216/250
# 750/750 [==============================] - 0s 242us/step - loss: 0.1578 - accuracy: 0.9413 - val_loss: 0.1394 - val_accuracy: 0.9440
# Epoch 217/250
# 750/750 [==============================] - 0s 256us/step - loss: 0.1585 - accuracy: 0.9400 - val_loss: 0.1384 - val_accuracy: 0.9440
# Epoch 218/250
# 750/750 [==============================] - 0s 399us/step - loss: 0.1577 - accuracy: 0.9413 - val_loss: 0.1377 - val_accuracy: 0.9440
# Epoch 219/250
# 750/750 [==============================] - 0s 242us/step - loss: 0.1566 - accuracy: 0.9413 - val_loss: 0.1374 - val_accuracy: 0.9480
# Epoch 220/250
# 750/750 [==============================] - 0s 353us/step - loss: 0.1570 - accuracy: 0.9413 - val_loss: 0.1373 - val_accuracy: 0.9480
# Epoch 221/250
# 750/750 [==============================] - 0s 369us/step - loss: 0.1558 - accuracy: 0.9413 - val_loss: 0.1378 - val_accuracy: 0.9440
# Epoch 222/250
# 750/750 [==============================] - 0s 304us/step - loss: 0.1550 - accuracy: 0.9440 - val_loss: 0.1374 - val_accuracy: 0.9440
# Epoch 223/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.1544 - accuracy: 0.9440 - val_loss: 0.1370 - val_accuracy: 0.9440
# Epoch 224/250
# 750/750 [==============================] - 0s 363us/step - loss: 0.1544 - accuracy: 0.9427 - val_loss: 0.1369 - val_accuracy: 0.9440
# Epoch 225/250
# 750/750 [==============================] - 0s 346us/step - loss: 0.1544 - accuracy: 0.9413 - val_loss: 0.1362 - val_accuracy: 0.9480
# Epoch 226/250
# 750/750 [==============================] - 0s 256us/step - loss: 0.1537 - accuracy: 0.9427 - val_loss: 0.1361 - val_accuracy: 0.9480
# Epoch 227/250
# 750/750 [==============================] - 0s 214us/step - loss: 0.1547 - accuracy: 0.9413 - val_loss: 0.1355 - val_accuracy: 0.9480
# Epoch 228/250
# 750/750 [==============================] - 0s 431us/step - loss: 0.1543 - accuracy: 0.9427 - val_loss: 0.1355 - val_accuracy: 0.9480
# Epoch 229/250
# 750/750 [==============================] - 0s 316us/step - loss: 0.1535 - accuracy: 0.9440 - val_loss: 0.1352 - val_accuracy: 0.9480
# Epoch 230/250
# 750/750 [==============================] - 0s 380us/step - loss: 0.1530 - accuracy: 0.9440 - val_loss: 0.1356 - val_accuracy: 0.9480
# Epoch 231/250
# 750/750 [==============================] - 0s 303us/step - loss: 0.1531 - accuracy: 0.9427 - val_loss: 0.1349 - val_accuracy: 0.9480
# Epoch 232/250
# 750/750 [==============================] - 0s 341us/step - loss: 0.1530 - accuracy: 0.9427 - val_loss: 0.1349 - val_accuracy: 0.9480
# Epoch 233/250
# 750/750 [==============================] - 0s 280us/step - loss: 0.1534 - accuracy: 0.9440 - val_loss: 0.1346 - val_accuracy: 0.9480
# Epoch 234/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.1521 - accuracy: 0.9440 - val_loss: 0.1344 - val_accuracy: 0.9480
# Epoch 235/250
# 750/750 [==============================] - 0s 345us/step - loss: 0.1512 - accuracy: 0.9440 - val_loss: 0.1336 - val_accuracy: 0.9480
# Epoch 236/250
# 750/750 [==============================] - 0s 296us/step - loss: 0.1504 - accuracy: 0.9453 - val_loss: 0.1332 - val_accuracy: 0.9480
# Epoch 237/250
# 750/750 [==============================] - 0s 389us/step - loss: 0.1514 - accuracy: 0.9440 - val_loss: 0.1333 - val_accuracy: 0.9480
# Epoch 238/250
# 750/750 [==============================] - 0s 441us/step - loss: 0.1504 - accuracy: 0.9453 - val_loss: 0.1329 - val_accuracy: 0.9480
# Epoch 239/250
# 750/750 [==============================] - 0s 236us/step - loss: 0.1504 - accuracy: 0.9453 - val_loss: 0.1331 - val_accuracy: 0.9480
# Epoch 240/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.1497 - accuracy: 0.9440 - val_loss: 0.1328 - val_accuracy: 0.9480
# Epoch 241/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.1494 - accuracy: 0.9453 - val_loss: 0.1323 - val_accuracy: 0.9480
# Epoch 242/250
# 750/750 [==============================] - 0s 339us/step - loss: 0.1491 - accuracy: 0.9467 - val_loss: 0.1321 - val_accuracy: 0.9480
# Epoch 243/250
# 750/750 [==============================] - 0s 301us/step - loss: 0.1475 - accuracy: 0.9467 - val_loss: 0.1311 - val_accuracy: 0.9480
# Epoch 244/250
# 750/750 [==============================] - 0s 330us/step - loss: 0.1468 - accuracy: 0.9480 - val_loss: 0.1304 - val_accuracy: 0.9480
# Epoch 245/250
# 750/750 [==============================] - 0s 397us/step - loss: 0.1466 - accuracy: 0.9480 - val_loss: 0.1298 - val_accuracy: 0.9480
# Epoch 246/250
# 750/750 [==============================] - 0s 396us/step - loss: 0.1464 - accuracy: 0.9480 - val_loss: 0.1296 - val_accuracy: 0.9480
# Epoch 247/250
# 750/750 [==============================] - 0s 296us/step - loss: 0.1460 - accuracy: 0.9467 - val_loss: 0.1295 - val_accuracy: 0.9520
# Epoch 248/250
# 750/750 [==============================] - 0s 388us/step - loss: 0.1467 - accuracy: 0.9467 - val_loss: 0.1289 - val_accuracy: 0.9520
# Epoch 249/250
# 750/750 [==============================] - 0s 328us/step - loss: 0.1451 - accuracy: 0.9467 - val_loss: 0.1284 - val_accuracy: 0.9520
# Epoch 250/250
# 750/750 [==============================] - 0s 344us/step - loss: 0.1447 - accuracy: 0.9480 - val_loss: 0.1281 - val_accuracy: 0.9520

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %% [markdown]
# Notar que se agregaron una keys, asociadas al set de validación. Grafiquemos.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ¿Cuántos parámetros tiene ahora el modelo?

# %%
print(model.get_weights())
# Out:
# [array([[ 0.03429746, -0.5824627 ,  0.057898  , -0.9258558 ,  0.03276408,
#          1.4833155 ,  1.3692769 ,  0.04904625, -0.6117766 ,  0.05596864],
#        [ 0.8346635 , -0.05061145,  1.2608273 , -0.08536427,  0.8112257 ,
#          0.31193367, -1.3408302 ,  1.1056024 , -0.05184741,  1.2484288 ]],
#       dtype=float32), array([-0.34630978, -0.31720895, -0.5242559 , -0.5031776 , -0.33623958,
#         0.78401995, -0.4219547 , -0.45919612, -0.3332453 , -0.5181907 ],
#       dtype=float32), array([[-1.9742147],
#        [-4.042485 ],
#        [-1.6598526],
#        [-4.2702284],
#        [-1.583005 ],
#        [-1.0074389],
#        [ 2.2981265],
#        [-2.103604 ],
#        [-4.2109857],
#        [-1.8532741]], dtype=float32), array([0.98399067], dtype=float32)]

# %% [markdown]
# Y graficamos las fronteras de decisión. ¿Notan que ya no es una frontera abrupta, sino que hay una zona de cambio?¿A qué se debe?

# %%
plt.figure(figsize = (10,6))

ax = sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, levels = 10, alpha=0.3, cmap = 'plasma')
plt.show()

# %% [markdown]
# **Ejercicio:** volver a correr esta sección, pero reemplazando la función que genera los datos `make_blobs` por `make_moons`. ¿Qué problema ven en el resultado?
#
# **Ejercicio**: con los datos producidos por `make_moons`, agregar una capa a la red neuronal, con 10 neuronas y función de activación `relu`.

# %% [markdown]
# ## 2. MNIST
#
# El dataset de MNIST es un dataset muy conocido. Consiste en dígitos escritos a mano. Muchas modelos de redes neuronales son probados primeros en este set. Pueden encontrar una descripción más detallada, y un ranking de modelos con su desempeño, en el siguiente link.
#
# https://en.wikipedia.org/wiki/MNIST_database
#
# Vamos a arrancar con una sola capa, con una activación `softmax`, ya que se trata de diez clases.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import random
from sklearn.model_selection import train_test_split
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import keras

# %% [markdown]
# **1. Carga de datos**
#
# Cada instancia del dataset es una imagen guardada en una carpeta con la etiqueta correspondiente.

# %%
directorio = 'MNIST/'

# %% [markdown]
# Miramos las carpetas que hay adentro de la carpeta MNIST

# %%
print(os.listdir(directorio))
# Out:
# ['0', '2', '7', '5', '4', '6', '1', '3', '9', '8']

# %% [markdown]
# Creamos los contenedores vacíos

# %%
todas_imagenes = []
y_todas_imagenes = []

# %% [markdown]
# y los llenamos.

# %%
digitos = np.arange(0,10)
for digito in digitos:
    directorio = 'MNIST/' + str(digito) + '/'
    print(digito, directorio)
    print('Hay', len(os.listdir(directorio)),'imagenes')
    for imagen in os.listdir(directorio):
        todas_imagenes.append(plt.imread(directorio + imagen))
        y_todas_imagenes.append(digito)
        
todas_imagenes = np.array(todas_imagenes)
y_todas_imagenes = np.array(y_todas_imagenes)
# Out:
# 0 MNIST/0/
# Hay 4132 imagenes
# 1 MNIST/1/
# Hay 4684 imagenes
# 2 MNIST/2/
# Hay 4177 imagenes
# 3 MNIST/3/
# Hay 4351 imagenes
# 4 MNIST/4/
# Hay 4072 imagenes
# 5 MNIST/5/
# Hay 3795 imagenes
# 6 MNIST/6/
# Hay 4137 imagenes
# 7 MNIST/7/
# Hay 4401 imagenes
# 8 MNIST/8/
# Hay 4063 imagenes
# 9 MNIST/9/
# Hay 4188 imagenes

# %% [markdown]
# **2. Preprocesado**
#
# **Ejercicio:** Mirar el `shape` de `X` y responder: ¿Cuántas instancias son?¿Qué ancho y largo tienen las imágenes?¿Cuántas bandas?

# %%
print(todas_imagenes.shape, y_todas_imagenes.shape)
n_instancias = todas_imagenes.shape[0]
ancho_imagen = todas_imagenes.shape[1]
largo_imagen = todas_imagenes.shape[2]
# Out:
# (42000, 28, 28) (42000,)

# %% [markdown]
# Miramos una imagen al azar.

# %%
idx_imagen = np.random.randint(0,todas_imagenes.shape[0])
plt.figure(figsize = (6,6))
plt.title('Es un ' + str(y_todas_imagenes[idx_imagen]))
plt.imshow(todas_imagenes[idx_imagen, :, :])
plt.show()

# %% [markdown]
# **Ejercicio:** Crear un arreglo `X` que sea igual a `todas_imagenes`, pero de forma `(n_instancias, largo_imagen * ancho_imagen)`.

# %%
X = todas_imagenes.reshape(n_instancias, largo_imagen*ancho_imagen)
print(X.shape)
# Out:
# (42000, 784)

# %% [markdown]
# **Ejercicio:** Reescalar las imágenes entre 0 y 1.

# %%
X = X/255

# %% [markdown]
# **Ejercicio:** usar el `to_categorical` de Keras para llevar `y_todas_imagenes` a una columna con unos y ceros para cada clase `y` (One Hot Encoding).

# %%
from keras.utils import to_categorical
y = to_categorical(y_todas_imagenes)
print(y.shape)
# Out:
# (42000, 10)

# %% [markdown]
# **Ejercicio:** hacer un `train_test_split`. Usar el 20% del dataset como conjunto de test.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify = y)

# %% [markdown]
# **3. Entrenamiento del modelo**
#
# Comenzar entrenando un Red Neuronal de una capa, con diez neuronas, función de activación `softmax` y pérdida `categorical_crossentropy`. Usar como optimizador `Adam` y `epoch = 20`.

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout

model = Sequential()
#model.add(Dense(16, activation='relu'))
#model.add(Dense(8, activation='relu'))
#model.add(Dense(800, activation='relu'))
model.add(Dense(10, activation='softmax'))
optimizador = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizador,loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Train on 30240 samples, validate on 3360 samples
# Epoch 1/10
# 30240/30240 [==============================] - 9s 302us/step - loss: 0.5945 - accuracy: 0.8500 - val_loss: 0.3673 - val_accuracy: 0.9009
# Epoch 2/10
# 30240/30240 [==============================] - 9s 288us/step - loss: 0.3349 - accuracy: 0.9081 - val_loss: 0.3114 - val_accuracy: 0.9164
# Epoch 3/10
# 30240/30240 [==============================] - 9s 287us/step - loss: 0.2986 - accuracy: 0.9168 - val_loss: 0.2890 - val_accuracy: 0.9220
# Epoch 4/10
# 30240/30240 [==============================] - 13s 417us/step - loss: 0.2815 - accuracy: 0.9211 - val_loss: 0.2795 - val_accuracy: 0.9235
# Epoch 5/10
# 30240/30240 [==============================] - 14s 470us/step - loss: 0.2697 - accuracy: 0.9247 - val_loss: 0.2722 - val_accuracy: 0.9262
# Epoch 6/10
# 30240/30240 [==============================] - 18s 596us/step - loss: 0.2613 - accuracy: 0.9269 - val_loss: 0.2687 - val_accuracy: 0.9238
# Epoch 7/10
# 30240/30240 [==============================] - 19s 627us/step - loss: 0.2550 - accuracy: 0.9286 - val_loss: 0.2648 - val_accuracy: 0.9274
# Epoch 8/10
# 30240/30240 [==============================] - 11s 369us/step - loss: 0.2500 - accuracy: 0.9313 - val_loss: 0.2630 - val_accuracy: 0.9265
# Epoch 9/10
# 30240/30240 [==============================] - 10s 339us/step - loss: 0.2445 - accuracy: 0.9327 - val_loss: 0.2592 - val_accuracy: 0.9283
# Epoch 10/10
# 30240/30240 [==============================] - 10s 330us/step - loss: 0.2409 - accuracy: 0.9330 - val_loss: 0.2617 - val_accuracy: 0.9259

# %% [markdown]
# **Ejercicio:** ¿cuántos parámetros tiene el modelo? Recordar que hay una función de Keras que hace un *informe* de la red neuronal.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Ejercicio:** Graficar la pérdida y la exactitud en función de *epochs* para validación y entrenamiento.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **4. Evaluación de los resultados.**
#
# **Ejercicio**: predecir las etiquetas de todo el set de testeo.

# %%
y_test_pred = model.predict(X_test)

# %% [markdown]
# Esto sirve para pasar de probabilidades a la etiqueta en sí. En este caso, la etiqueta es el dígito, y corresponde al número de columna.

# %%
y_test_pred = np.argmax(y_test_pred, axis = 1)
y_test_pred.shape
# Out:
# (8400,)

# %% [markdown]
# **Ejercicio:** Calcular exactitud y la matriz de confusión para el conjunto de entrenamiento.

# %%
from sklearn.metrics import confusion_matrix

y_test = np.argmax(y_test,axis = 1)
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[806,   0,   0,   1,   0,   5,   5,   1,   8,   1],
#        [  0, 921,   3,   4,   1,   2,   1,   2,   2,   1],
#        [  8,  16, 753,  17,   4,   5,   6,   8,  17,   1],
#        [  5,   1,  19, 786,   0,  31,   0,   8,  15,   5],
#        [  6,   2,   6,   0, 759,   3,   6,   1,   4,  27],
#        [  9,   4,   9,  27,  13, 653,   9,   5,  20,  10],
#        [ 10,   1,   5,   0,   3,  10, 794,   2,   2,   0],
#        [  6,   4,  15,   4,   8,   1,   1, 803,   1,  37],
#        [  3,  24,  10,  17,   3,  23,   3,   6, 711,  13],
#        [  4,   3,   3,  11,  20,   9,   0,  33,   7, 748]])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_test_pred)
# Out:
# 0.9207142857142857

# %% [markdown]
# **Ejercicio:** ¿Dónde se está confundiendo? Graficar algunos ejemplos.

# %%
errores = y_test != y_test_pred

# %%
imagenes_errores = X_test[errores,:]
y_test_errores = y_test[errores]
y_test_pred_errores = y_test_pred[errores]
print(imagenes_errores.shape)
# Out:
# (666, 784)

# %%
imagenes_errores = imagenes_errores.reshape(imagenes_errores.shape[0], ancho_imagen, largo_imagen)
print(imagenes_errores.shape)
# Out:
# (666, 28, 28)

# %%
idx_imagen = np.random.randint(0,imagenes_errores.shape[0])
plt.figure(figsize = (6,6))
plt.title('Es un ' + str(y_test_errores[idx_imagen]) +'. Fue etiquetado como ' + str(y_test_pred_errores[idx_imagen]))
plt.imshow(imagenes_errores[idx_imagen, :, :])
plt.show()

# %% [markdown]
# **Ejercicio:** Volver a entrenar, pero agregando una capa con 800 neuronas y función de activación `relu`.

# %% [markdown]
# **Extra:** En el caso del Perceptrón de una sola capa (10 neuronas de salida y nada más), ¿qué está viendo la red?
#
# Notar que los parámetros para cualquiera de las neuronas de salida son 784 + Bias. Como hay 10 neuronas, son 7850 parámetros. Keras, con las función `model.get_weights()`, devuelve todos los pesos y *biases* de cada neurona. Seleccionado la primera componente, descartamos los *biases*.

# %%
ws = model.get_weights()[0]
print(ws.shape)
# Out:
# (784, 10)

# %% [markdown]
# Notar que son 784: un peso por cada pixel de la imagen - sin el bias - por diez neuronas.
#
# Como son 784, podemos llevarlos a la forma `(28,28)` y graficarlos como si fueran una imagen. Hacemos eso para todas las neuronas.

# %%
plt.figure(figsize = (20,10))
for i in range(10):
    plt.subplot(2,5,i+1)
    w0 = ws[:,i]
    plt.title(i)
    plt.imshow(w0.reshape(28,28))
plt.tight_layout()
plt.show()
