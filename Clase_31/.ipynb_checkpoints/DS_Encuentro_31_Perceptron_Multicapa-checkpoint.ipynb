# %% [markdown]
# # Redes Neuronales
#
# En este notebook vamos a construir la unidad básica de las redes neuronales, el Perceptrón. Tiene dos partes:
# 1. **Perceptrón 2D**: vamos a entrenar un Perceptrón con Keras sobre un dataset ficticio. Exploramos cómo son las fronteras en 2D. Limitaciones del Perceptrón. Generamos un dataset no-linealmente separable y vemos cómo responde el Perceptrón.
# 2. **MNIST**: vamos a trabajar con este conocido dataset. El objetivo es identificar dígitos, del 0 al 9, escritos a manos. Primero entrenaremos una red neuronal de una capa y luego una Red Neuronal de más capas.
#
# ## 1. Perceptrón en 2D
#
# Vamos a generar un dataset sintético con unas funciones que ya vienen incorporadas en scikit-learn.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from sklearn.datasets.samples_generator import make_blobs, make_moons, make_circles

#X, y = make_blobs(n_samples=1000, centers=2, n_features=2,random_state=0)
X, y = make_moons(n_samples=1000, random_state=0)
#X, y = make_circles(n_samples=1000, random_state=0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Reescalamos los datos

# %%
X[:,0] = (X[:,0] - X[:,0].mean())/X[:,0].std()
X[:,1] = (X[:,1] - X[:,1].mean())/X[:,1].std()

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Definimos el modelo a entrenar y volvemos a mirar algunas de sus características.

# %%
model = Sequential()
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs=250, validation_split=0.25) #Prueben con mas epochs
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/250
# 750/750 [==============================] - 1s 1ms/step - loss: 0.6076 - accuracy: 0.7027 - val_loss: 0.6048 - val_accuracy: 0.7120
# Epoch 2/250
# 750/750 [==============================] - 0s 309us/step - loss: 0.5771 - accuracy: 0.7347 - val_loss: 0.5766 - val_accuracy: 0.7360
# Epoch 3/250
# 750/750 [==============================] - 0s 340us/step - loss: 0.5520 - accuracy: 0.7720 - val_loss: 0.5536 - val_accuracy: 0.7600
# Epoch 4/250
# 750/750 [==============================] - 0s 323us/step - loss: 0.5315 - accuracy: 0.7920 - val_loss: 0.5334 - val_accuracy: 0.7800
# Epoch 5/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.5139 - accuracy: 0.8107 - val_loss: 0.5161 - val_accuracy: 0.8080
# Epoch 6/250
# 750/750 [==============================] - 0s 388us/step - loss: 0.4993 - accuracy: 0.8280 - val_loss: 0.5010 - val_accuracy: 0.8280
# Epoch 7/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.4869 - accuracy: 0.8427 - val_loss: 0.4885 - val_accuracy: 0.8320
# Epoch 8/250
# 750/750 [==============================] - 0s 330us/step - loss: 0.4764 - accuracy: 0.8533 - val_loss: 0.4771 - val_accuracy: 0.8480
# Epoch 9/250
# 750/750 [==============================] - 0s 370us/step - loss: 0.4663 - accuracy: 0.8587 - val_loss: 0.4658 - val_accuracy: 0.8600
# Epoch 10/250
# 750/750 [==============================] - 0s 301us/step - loss: 0.4567 - accuracy: 0.8653 - val_loss: 0.4559 - val_accuracy: 0.8640
# Epoch 11/250
# 750/750 [==============================] - 0s 270us/step - loss: 0.4482 - accuracy: 0.8693 - val_loss: 0.4466 - val_accuracy: 0.8720
# Epoch 12/250
# 750/750 [==============================] - 0s 275us/step - loss: 0.4405 - accuracy: 0.8707 - val_loss: 0.4380 - val_accuracy: 0.8720
# Epoch 13/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.4326 - accuracy: 0.8720 - val_loss: 0.4294 - val_accuracy: 0.8760
# Epoch 14/250
# 750/750 [==============================] - 0s 273us/step - loss: 0.4254 - accuracy: 0.8747 - val_loss: 0.4217 - val_accuracy: 0.8760
# Epoch 15/250
# 750/750 [==============================] - 0s 302us/step - loss: 0.4187 - accuracy: 0.8773 - val_loss: 0.4146 - val_accuracy: 0.8760
# Epoch 16/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.4125 - accuracy: 0.8787 - val_loss: 0.4078 - val_accuracy: 0.8720
# Epoch 17/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.4065 - accuracy: 0.8813 - val_loss: 0.4017 - val_accuracy: 0.8720
# Epoch 18/250
# 750/750 [==============================] - 0s 247us/step - loss: 0.4007 - accuracy: 0.8800 - val_loss: 0.3955 - val_accuracy: 0.8720
# Epoch 19/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.3951 - accuracy: 0.8813 - val_loss: 0.3898 - val_accuracy: 0.8720
# Epoch 20/250
# 750/750 [==============================] - 0s 267us/step - loss: 0.3896 - accuracy: 0.8813 - val_loss: 0.3841 - val_accuracy: 0.8760
# Epoch 21/250
# 750/750 [==============================] - 0s 315us/step - loss: 0.3841 - accuracy: 0.8813 - val_loss: 0.3784 - val_accuracy: 0.8760
# Epoch 22/250
# 750/750 [==============================] - 0s 343us/step - loss: 0.3786 - accuracy: 0.8800 - val_loss: 0.3729 - val_accuracy: 0.8760
# Epoch 23/250
# 750/750 [==============================] - 0s 282us/step - loss: 0.3729 - accuracy: 0.8813 - val_loss: 0.3669 - val_accuracy: 0.8760
# Epoch 24/250
# 750/750 [==============================] - 0s 365us/step - loss: 0.3674 - accuracy: 0.8827 - val_loss: 0.3612 - val_accuracy: 0.8800
# Epoch 25/250
# 750/750 [==============================] - 0s 316us/step - loss: 0.3615 - accuracy: 0.8827 - val_loss: 0.3552 - val_accuracy: 0.8760
# Epoch 26/250
# 750/750 [==============================] - 0s 235us/step - loss: 0.3556 - accuracy: 0.8840 - val_loss: 0.3491 - val_accuracy: 0.8760
# Epoch 27/250
# 750/750 [==============================] - 0s 338us/step - loss: 0.3493 - accuracy: 0.8827 - val_loss: 0.3430 - val_accuracy: 0.8760
# Epoch 28/250
# 750/750 [==============================] - 0s 357us/step - loss: 0.3434 - accuracy: 0.8827 - val_loss: 0.3378 - val_accuracy: 0.8760
# Epoch 29/250
# 750/750 [==============================] - 0s 267us/step - loss: 0.3385 - accuracy: 0.8840 - val_loss: 0.3327 - val_accuracy: 0.8760
# Epoch 30/250
# 750/750 [==============================] - 0s 346us/step - loss: 0.3332 - accuracy: 0.8840 - val_loss: 0.3271 - val_accuracy: 0.8760
# Epoch 31/250
# 750/750 [==============================] - 0s 377us/step - loss: 0.3286 - accuracy: 0.8853 - val_loss: 0.3218 - val_accuracy: 0.8760
# Epoch 32/250
# 750/750 [==============================] - 0s 343us/step - loss: 0.3237 - accuracy: 0.8853 - val_loss: 0.3169 - val_accuracy: 0.8760
# Epoch 33/250
# 750/750 [==============================] - 0s 303us/step - loss: 0.3196 - accuracy: 0.8867 - val_loss: 0.3119 - val_accuracy: 0.8760
# Epoch 34/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.3148 - accuracy: 0.8853 - val_loss: 0.3070 - val_accuracy: 0.8760
# Epoch 35/250
# 750/750 [==============================] - 0s 376us/step - loss: 0.3102 - accuracy: 0.8880 - val_loss: 0.3021 - val_accuracy: 0.8760
# Epoch 36/250
# 750/750 [==============================] - 0s 357us/step - loss: 0.3060 - accuracy: 0.8880 - val_loss: 0.2972 - val_accuracy: 0.8760
# Epoch 37/250
# 750/750 [==============================] - 0s 333us/step - loss: 0.3015 - accuracy: 0.8880 - val_loss: 0.2928 - val_accuracy: 0.8800
# Epoch 38/250
# 750/750 [==============================] - 0s 364us/step - loss: 0.2975 - accuracy: 0.8880 - val_loss: 0.2882 - val_accuracy: 0.8800
# Epoch 39/250
# 750/750 [==============================] - 0s 418us/step - loss: 0.2938 - accuracy: 0.8880 - val_loss: 0.2836 - val_accuracy: 0.8800
# Epoch 40/250
# 750/750 [==============================] - 0s 307us/step - loss: 0.2899 - accuracy: 0.8893 - val_loss: 0.2794 - val_accuracy: 0.8840
# Epoch 41/250
# 750/750 [==============================] - 0s 367us/step - loss: 0.2863 - accuracy: 0.8893 - val_loss: 0.2751 - val_accuracy: 0.8840
# Epoch 42/250
# 750/750 [==============================] - 0s 307us/step - loss: 0.2828 - accuracy: 0.8920 - val_loss: 0.2713 - val_accuracy: 0.8840
# Epoch 43/250
# 750/750 [==============================] - 0s 391us/step - loss: 0.2797 - accuracy: 0.8933 - val_loss: 0.2677 - val_accuracy: 0.8840
# Epoch 44/250
# 750/750 [==============================] - 0s 280us/step - loss: 0.2766 - accuracy: 0.8933 - val_loss: 0.2642 - val_accuracy: 0.8840
# Epoch 45/250
# 750/750 [==============================] - 0s 283us/step - loss: 0.2736 - accuracy: 0.8933 - val_loss: 0.2605 - val_accuracy: 0.8880
# Epoch 46/250
# 750/750 [==============================] - 0s 288us/step - loss: 0.2710 - accuracy: 0.8947 - val_loss: 0.2575 - val_accuracy: 0.8880
# Epoch 47/250
# 750/750 [==============================] - 0s 337us/step - loss: 0.2685 - accuracy: 0.8947 - val_loss: 0.2548 - val_accuracy: 0.8920
# Epoch 48/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.2660 - accuracy: 0.8947 - val_loss: 0.2517 - val_accuracy: 0.8920
# Epoch 49/250
# 750/750 [==============================] - 0s 278us/step - loss: 0.2639 - accuracy: 0.8947 - val_loss: 0.2488 - val_accuracy: 0.8960
# Epoch 50/250
# 750/750 [==============================] - 0s 335us/step - loss: 0.2616 - accuracy: 0.8947 - val_loss: 0.2459 - val_accuracy: 0.8960
# Epoch 51/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.2594 - accuracy: 0.8960 - val_loss: 0.2431 - val_accuracy: 0.8960
# Epoch 52/250
# 750/750 [==============================] - 0s 339us/step - loss: 0.2572 - accuracy: 0.8987 - val_loss: 0.2405 - val_accuracy: 0.8960
# Epoch 53/250
# 750/750 [==============================] - 0s 320us/step - loss: 0.2550 - accuracy: 0.8973 - val_loss: 0.2376 - val_accuracy: 0.8960
# Epoch 54/250
# 750/750 [==============================] - 0s 302us/step - loss: 0.2532 - accuracy: 0.8987 - val_loss: 0.2356 - val_accuracy: 0.8960
# Epoch 55/250
# 750/750 [==============================] - 0s 285us/step - loss: 0.2514 - accuracy: 0.8987 - val_loss: 0.2337 - val_accuracy: 0.9000
# Epoch 56/250
# 750/750 [==============================] - 0s 302us/step - loss: 0.2497 - accuracy: 0.8987 - val_loss: 0.2315 - val_accuracy: 0.9000
# Epoch 57/250
# 750/750 [==============================] - 0s 278us/step - loss: 0.2483 - accuracy: 0.8987 - val_loss: 0.2297 - val_accuracy: 0.9040
# Epoch 58/250
# 750/750 [==============================] - 0s 286us/step - loss: 0.2466 - accuracy: 0.8987 - val_loss: 0.2276 - val_accuracy: 0.9040
# Epoch 59/250
# 750/750 [==============================] - 0s 259us/step - loss: 0.2450 - accuracy: 0.9000 - val_loss: 0.2258 - val_accuracy: 0.9040
# Epoch 60/250
# 750/750 [==============================] - 0s 212us/step - loss: 0.2434 - accuracy: 0.9000 - val_loss: 0.2236 - val_accuracy: 0.9040
# Epoch 61/250
# 750/750 [==============================] - 0s 200us/step - loss: 0.2417 - accuracy: 0.9000 - val_loss: 0.2216 - val_accuracy: 0.9040
# Epoch 62/250
# 750/750 [==============================] - 0s 239us/step - loss: 0.2405 - accuracy: 0.9013 - val_loss: 0.2201 - val_accuracy: 0.9040
# Epoch 63/250
# 750/750 [==============================] - 0s 284us/step - loss: 0.2392 - accuracy: 0.9013 - val_loss: 0.2187 - val_accuracy: 0.9040
# Epoch 64/250
# 750/750 [==============================] - 0s 205us/step - loss: 0.2380 - accuracy: 0.9013 - val_loss: 0.2174 - val_accuracy: 0.9080
# Epoch 65/250
# 750/750 [==============================] - 0s 231us/step - loss: 0.2367 - accuracy: 0.9013 - val_loss: 0.2159 - val_accuracy: 0.9080
# Epoch 66/250
# 750/750 [==============================] - 0s 229us/step - loss: 0.2355 - accuracy: 0.9013 - val_loss: 0.2147 - val_accuracy: 0.9080
# Epoch 67/250
# 750/750 [==============================] - 0s 276us/step - loss: 0.2346 - accuracy: 0.9000 - val_loss: 0.2132 - val_accuracy: 0.9080
# Epoch 68/250
# 750/750 [==============================] - 0s 311us/step - loss: 0.2332 - accuracy: 0.9000 - val_loss: 0.2113 - val_accuracy: 0.9120
# Epoch 69/250
# 750/750 [==============================] - 0s 209us/step - loss: 0.2317 - accuracy: 0.9013 - val_loss: 0.2096 - val_accuracy: 0.9120
# Epoch 70/250
# 750/750 [==============================] - 0s 256us/step - loss: 0.2303 - accuracy: 0.9013 - val_loss: 0.2081 - val_accuracy: 0.9160
# Epoch 71/250
# 750/750 [==============================] - 0s 304us/step - loss: 0.2290 - accuracy: 0.9013 - val_loss: 0.2066 - val_accuracy: 0.9160
# Epoch 72/250
# 750/750 [==============================] - 0s 266us/step - loss: 0.2278 - accuracy: 0.9013 - val_loss: 0.2051 - val_accuracy: 0.9160
# Epoch 73/250
# 750/750 [==============================] - 0s 241us/step - loss: 0.2266 - accuracy: 0.9027 - val_loss: 0.2038 - val_accuracy: 0.9160
# Epoch 74/250
# 750/750 [==============================] - 0s 260us/step - loss: 0.2256 - accuracy: 0.9027 - val_loss: 0.2028 - val_accuracy: 0.9160
# Epoch 75/250
# 750/750 [==============================] - 0s 293us/step - loss: 0.2245 - accuracy: 0.9027 - val_loss: 0.2014 - val_accuracy: 0.9160
# Epoch 76/250
# 750/750 [==============================] - 0s 303us/step - loss: 0.2230 - accuracy: 0.9040 - val_loss: 0.1999 - val_accuracy: 0.9160
# Epoch 77/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.2219 - accuracy: 0.9040 - val_loss: 0.1987 - val_accuracy: 0.9160
# Epoch 78/250
# 750/750 [==============================] - 0s 365us/step - loss: 0.2208 - accuracy: 0.9053 - val_loss: 0.1974 - val_accuracy: 0.9160
# Epoch 79/250
# 750/750 [==============================] - 0s 321us/step - loss: 0.2196 - accuracy: 0.9053 - val_loss: 0.1959 - val_accuracy: 0.9160
# Epoch 80/250
# 750/750 [==============================] - 0s 235us/step - loss: 0.2184 - accuracy: 0.9053 - val_loss: 0.1946 - val_accuracy: 0.9160
# Epoch 81/250
# 750/750 [==============================] - 0s 248us/step - loss: 0.2172 - accuracy: 0.9080 - val_loss: 0.1934 - val_accuracy: 0.9160
# Epoch 82/250
# 750/750 [==============================] - 0s 249us/step - loss: 0.2160 - accuracy: 0.9080 - val_loss: 0.1922 - val_accuracy: 0.9160
# Epoch 83/250
# 750/750 [==============================] - 0s 354us/step - loss: 0.2146 - accuracy: 0.9093 - val_loss: 0.1910 - val_accuracy: 0.9160
# Epoch 84/250
# 750/750 [==============================] - 0s 206us/step - loss: 0.2136 - accuracy: 0.9093 - val_loss: 0.1898 - val_accuracy: 0.9200
# Epoch 85/250
# 750/750 [==============================] - 0s 257us/step - loss: 0.2123 - accuracy: 0.9080 - val_loss: 0.1887 - val_accuracy: 0.9200
# Epoch 86/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.2110 - accuracy: 0.9080 - val_loss: 0.1876 - val_accuracy: 0.9240
# Epoch 87/250
# 750/750 [==============================] - 0s 295us/step - loss: 0.2096 - accuracy: 0.9080 - val_loss: 0.1862 - val_accuracy: 0.9240
# Epoch 88/250
# 750/750 [==============================] - 0s 247us/step - loss: 0.2083 - accuracy: 0.9080 - val_loss: 0.1849 - val_accuracy: 0.9240
# Epoch 89/250
# 750/750 [==============================] - 0s 245us/step - loss: 0.2072 - accuracy: 0.9093 - val_loss: 0.1841 - val_accuracy: 0.9240
# Epoch 90/250
# 750/750 [==============================] - 0s 245us/step - loss: 0.2062 - accuracy: 0.9093 - val_loss: 0.1829 - val_accuracy: 0.9240
# Epoch 91/250
# 750/750 [==============================] - 0s 228us/step - loss: 0.2049 - accuracy: 0.9107 - val_loss: 0.1817 - val_accuracy: 0.9240
# Epoch 92/250
# 750/750 [==============================] - 0s 287us/step - loss: 0.2036 - accuracy: 0.9107 - val_loss: 0.1806 - val_accuracy: 0.9240
# Epoch 93/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.2026 - accuracy: 0.9107 - val_loss: 0.1798 - val_accuracy: 0.9240
# Epoch 94/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.2015 - accuracy: 0.9107 - val_loss: 0.1782 - val_accuracy: 0.9240
# Epoch 95/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.1997 - accuracy: 0.9120 - val_loss: 0.1768 - val_accuracy: 0.9240
# Epoch 96/250
# 750/750 [==============================] - 0s 329us/step - loss: 0.1982 - accuracy: 0.9120 - val_loss: 0.1757 - val_accuracy: 0.9240
# Epoch 97/250
# 750/750 [==============================] - 0s 218us/step - loss: 0.1967 - accuracy: 0.9133 - val_loss: 0.1744 - val_accuracy: 0.9240
# Epoch 98/250
# 750/750 [==============================] - 0s 340us/step - loss: 0.1946 - accuracy: 0.9147 - val_loss: 0.1730 - val_accuracy: 0.9280
# Epoch 99/250
# 750/750 [==============================] - 0s 297us/step - loss: 0.1931 - accuracy: 0.9147 - val_loss: 0.1716 - val_accuracy: 0.9280
# Epoch 100/250
# 750/750 [==============================] - 0s 230us/step - loss: 0.1914 - accuracy: 0.9133 - val_loss: 0.1704 - val_accuracy: 0.9240
# Epoch 101/250
# 750/750 [==============================] - 0s 314us/step - loss: 0.1899 - accuracy: 0.9160 - val_loss: 0.1688 - val_accuracy: 0.9280
# Epoch 102/250
# 750/750 [==============================] - 0s 348us/step - loss: 0.1882 - accuracy: 0.9160 - val_loss: 0.1672 - val_accuracy: 0.9280
# Epoch 103/250
# 750/750 [==============================] - 0s 366us/step - loss: 0.1867 - accuracy: 0.9147 - val_loss: 0.1659 - val_accuracy: 0.9280
# Epoch 104/250
# 750/750 [==============================] - 0s 308us/step - loss: 0.1849 - accuracy: 0.9160 - val_loss: 0.1643 - val_accuracy: 0.9320
# Epoch 105/250
# 750/750 [==============================] - 0s 361us/step - loss: 0.1832 - accuracy: 0.9160 - val_loss: 0.1624 - val_accuracy: 0.9360
# Epoch 106/250
# 750/750 [==============================] - 0s 280us/step - loss: 0.1810 - accuracy: 0.9160 - val_loss: 0.1608 - val_accuracy: 0.9360
# Epoch 107/250
# 750/750 [==============================] - 0s 278us/step - loss: 0.1789 - accuracy: 0.9173 - val_loss: 0.1588 - val_accuracy: 0.9360
# Epoch 108/250
# 750/750 [==============================] - 0s 334us/step - loss: 0.1771 - accuracy: 0.9187 - val_loss: 0.1572 - val_accuracy: 0.9360
# Epoch 109/250
# 750/750 [==============================] - 0s 341us/step - loss: 0.1751 - accuracy: 0.9200 - val_loss: 0.1552 - val_accuracy: 0.9400
# Epoch 110/250
# 750/750 [==============================] - 0s 282us/step - loss: 0.1730 - accuracy: 0.9200 - val_loss: 0.1536 - val_accuracy: 0.9400
# Epoch 111/250
# 750/750 [==============================] - 0s 247us/step - loss: 0.1712 - accuracy: 0.9200 - val_loss: 0.1519 - val_accuracy: 0.9400
# Epoch 112/250
# 750/750 [==============================] - 0s 323us/step - loss: 0.1691 - accuracy: 0.9213 - val_loss: 0.1499 - val_accuracy: 0.9400
# Epoch 113/250
# 750/750 [==============================] - 0s 335us/step - loss: 0.1672 - accuracy: 0.9227 - val_loss: 0.1481 - val_accuracy: 0.9400
# Epoch 114/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.1650 - accuracy: 0.9240 - val_loss: 0.1462 - val_accuracy: 0.9400
# Epoch 115/250
# 750/750 [==============================] - 0s 293us/step - loss: 0.1627 - accuracy: 0.9253 - val_loss: 0.1440 - val_accuracy: 0.9400
# Epoch 116/250
# 750/750 [==============================] - 0s 341us/step - loss: 0.1603 - accuracy: 0.9253 - val_loss: 0.1420 - val_accuracy: 0.9400
# Epoch 117/250
# 750/750 [==============================] - 0s 355us/step - loss: 0.1582 - accuracy: 0.9280 - val_loss: 0.1402 - val_accuracy: 0.9400
# Epoch 118/250
# 750/750 [==============================] - 0s 283us/step - loss: 0.1562 - accuracy: 0.9293 - val_loss: 0.1385 - val_accuracy: 0.9400
# Epoch 119/250
# 750/750 [==============================] - 0s 304us/step - loss: 0.1543 - accuracy: 0.9307 - val_loss: 0.1367 - val_accuracy: 0.9400
# Epoch 120/250
# 750/750 [==============================] - 0s 305us/step - loss: 0.1523 - accuracy: 0.9307 - val_loss: 0.1347 - val_accuracy: 0.9440
# Epoch 121/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.1503 - accuracy: 0.9307 - val_loss: 0.1332 - val_accuracy: 0.9440
# Epoch 122/250
# 750/750 [==============================] - 0s 296us/step - loss: 0.1486 - accuracy: 0.9320 - val_loss: 0.1313 - val_accuracy: 0.9440
# Epoch 123/250
# 750/750 [==============================] - 0s 230us/step - loss: 0.1465 - accuracy: 0.9347 - val_loss: 0.1295 - val_accuracy: 0.9440
# Epoch 124/250
# 750/750 [==============================] - 0s 262us/step - loss: 0.1446 - accuracy: 0.9347 - val_loss: 0.1277 - val_accuracy: 0.9520
# Epoch 125/250
# 750/750 [==============================] - 0s 294us/step - loss: 0.1426 - accuracy: 0.9347 - val_loss: 0.1258 - val_accuracy: 0.9520
# Epoch 126/250
# 750/750 [==============================] - 0s 347us/step - loss: 0.1407 - accuracy: 0.9360 - val_loss: 0.1242 - val_accuracy: 0.9520
# Epoch 127/250
# 750/750 [==============================] - 0s 258us/step - loss: 0.1392 - accuracy: 0.9360 - val_loss: 0.1225 - val_accuracy: 0.9520
# Epoch 128/250
# 750/750 [==============================] - 0s 243us/step - loss: 0.1371 - accuracy: 0.9400 - val_loss: 0.1208 - val_accuracy: 0.9520
# Epoch 129/250
# 750/750 [==============================] - 0s 307us/step - loss: 0.1354 - accuracy: 0.9400 - val_loss: 0.1190 - val_accuracy: 0.9520
# Epoch 130/250
# 750/750 [==============================] - 0s 383us/step - loss: 0.1334 - accuracy: 0.9427 - val_loss: 0.1172 - val_accuracy: 0.9520
# Epoch 131/250
# 750/750 [==============================] - 0s 231us/step - loss: 0.1315 - accuracy: 0.9440 - val_loss: 0.1156 - val_accuracy: 0.9520
# Epoch 132/250
# 750/750 [==============================] - 0s 270us/step - loss: 0.1299 - accuracy: 0.9440 - val_loss: 0.1142 - val_accuracy: 0.9520
# Epoch 133/250
# 750/750 [==============================] - 0s 303us/step - loss: 0.1284 - accuracy: 0.9467 - val_loss: 0.1124 - val_accuracy: 0.9520
# Epoch 134/250
# 750/750 [==============================] - 0s 321us/step - loss: 0.1266 - accuracy: 0.9467 - val_loss: 0.1110 - val_accuracy: 0.9520
# Epoch 135/250
# 750/750 [==============================] - 0s 320us/step - loss: 0.1251 - accuracy: 0.9467 - val_loss: 0.1095 - val_accuracy: 0.9560
# Epoch 136/250
# 750/750 [==============================] - 0s 256us/step - loss: 0.1234 - accuracy: 0.9480 - val_loss: 0.1081 - val_accuracy: 0.9560
# Epoch 137/250
# 750/750 [==============================] - 0s 302us/step - loss: 0.1217 - accuracy: 0.9480 - val_loss: 0.1063 - val_accuracy: 0.9560
# Epoch 138/250
# 750/750 [==============================] - 0s 346us/step - loss: 0.1201 - accuracy: 0.9493 - val_loss: 0.1047 - val_accuracy: 0.9560
# Epoch 139/250
# 750/750 [==============================] - 0s 325us/step - loss: 0.1182 - accuracy: 0.9520 - val_loss: 0.1032 - val_accuracy: 0.9560
# Epoch 140/250
# 750/750 [==============================] - 0s 272us/step - loss: 0.1170 - accuracy: 0.9507 - val_loss: 0.1021 - val_accuracy: 0.9560
# Epoch 141/250
# 750/750 [==============================] - 0s 300us/step - loss: 0.1157 - accuracy: 0.9520 - val_loss: 0.1005 - val_accuracy: 0.9560
# Epoch 142/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.1140 - accuracy: 0.9533 - val_loss: 0.0991 - val_accuracy: 0.9560
# Epoch 143/250
# 750/750 [==============================] - 0s 344us/step - loss: 0.1125 - accuracy: 0.9533 - val_loss: 0.0977 - val_accuracy: 0.9560
# Epoch 144/250
# 750/750 [==============================] - 0s 223us/step - loss: 0.1110 - accuracy: 0.9547 - val_loss: 0.0961 - val_accuracy: 0.9600
# Epoch 145/250
# 750/750 [==============================] - 0s 233us/step - loss: 0.1093 - accuracy: 0.9547 - val_loss: 0.0948 - val_accuracy: 0.9640
# Epoch 146/250
# 750/750 [==============================] - 0s 272us/step - loss: 0.1080 - accuracy: 0.9560 - val_loss: 0.0935 - val_accuracy: 0.9640
# Epoch 147/250
# 750/750 [==============================] - 0s 246us/step - loss: 0.1067 - accuracy: 0.9547 - val_loss: 0.0919 - val_accuracy: 0.9640
# Epoch 148/250
# 750/750 [==============================] - 0s 291us/step - loss: 0.1051 - accuracy: 0.9560 - val_loss: 0.0907 - val_accuracy: 0.9640
# Epoch 149/250
# 750/750 [==============================] - 0s 275us/step - loss: 0.1038 - accuracy: 0.9587 - val_loss: 0.0894 - val_accuracy: 0.9680
# Epoch 150/250
# 750/750 [==============================] - 0s 332us/step - loss: 0.1024 - accuracy: 0.9587 - val_loss: 0.0882 - val_accuracy: 0.9680
# Epoch 151/250
# 750/750 [==============================] - 0s 248us/step - loss: 0.1011 - accuracy: 0.9587 - val_loss: 0.0868 - val_accuracy: 0.9720
# Epoch 152/250
# 750/750 [==============================] - 0s 342us/step - loss: 0.1001 - accuracy: 0.9587 - val_loss: 0.0857 - val_accuracy: 0.9760
# Epoch 153/250
# 750/750 [==============================] - 0s 309us/step - loss: 0.0987 - accuracy: 0.9587 - val_loss: 0.0845 - val_accuracy: 0.9760
# Epoch 154/250
# 750/750 [==============================] - 0s 271us/step - loss: 0.0974 - accuracy: 0.9600 - val_loss: 0.0831 - val_accuracy: 0.9760
# Epoch 155/250
# 750/750 [==============================] - 0s 285us/step - loss: 0.0956 - accuracy: 0.9600 - val_loss: 0.0816 - val_accuracy: 0.9800
# Epoch 156/250
# 750/750 [==============================] - 0s 323us/step - loss: 0.0941 - accuracy: 0.9600 - val_loss: 0.0805 - val_accuracy: 0.9800
# Epoch 157/250
# 750/750 [==============================] - 0s 322us/step - loss: 0.0929 - accuracy: 0.9613 - val_loss: 0.0792 - val_accuracy: 0.9800
# Epoch 158/250
# 750/750 [==============================] - 0s 309us/step - loss: 0.0914 - accuracy: 0.9613 - val_loss: 0.0781 - val_accuracy: 0.9800
# Epoch 159/250
# 750/750 [==============================] - 0s 289us/step - loss: 0.0902 - accuracy: 0.9640 - val_loss: 0.0769 - val_accuracy: 0.9800
# Epoch 160/250
# 750/750 [==============================] - 0s 266us/step - loss: 0.0885 - accuracy: 0.9653 - val_loss: 0.0755 - val_accuracy: 0.9840
# Epoch 161/250
# 750/750 [==============================] - 0s 275us/step - loss: 0.0871 - accuracy: 0.9653 - val_loss: 0.0741 - val_accuracy: 0.9880
# Epoch 162/250
# 750/750 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.96 - 0s 265us/step - loss: 0.0859 - accuracy: 0.9653 - val_loss: 0.0729 - val_accuracy: 0.9880
# Epoch 163/250
# 750/750 [==============================] - 0s 220us/step - loss: 0.0846 - accuracy: 0.9653 - val_loss: 0.0718 - val_accuracy: 0.9880
# Epoch 164/250
# 750/750 [==============================] - 0s 218us/step - loss: 0.0831 - accuracy: 0.9667 - val_loss: 0.0705 - val_accuracy: 0.9880
# Epoch 165/250
# 750/750 [==============================] - 0s 235us/step - loss: 0.0818 - accuracy: 0.9693 - val_loss: 0.0695 - val_accuracy: 0.9880
# Epoch 166/250
# 750/750 [==============================] - 0s 224us/step - loss: 0.0807 - accuracy: 0.9707 - val_loss: 0.0683 - val_accuracy: 0.9880
# Epoch 167/250
# 750/750 [==============================] - 0s 230us/step - loss: 0.0793 - accuracy: 0.9720 - val_loss: 0.0672 - val_accuracy: 0.9880
# Epoch 168/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.0779 - accuracy: 0.9733 - val_loss: 0.0660 - val_accuracy: 0.9880
# Epoch 169/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.0770 - accuracy: 0.9733 - val_loss: 0.0649 - val_accuracy: 0.9880
# Epoch 170/250
# 750/750 [==============================] - 0s 295us/step - loss: 0.0757 - accuracy: 0.9733 - val_loss: 0.0637 - val_accuracy: 0.9920
# Epoch 171/250
# 750/750 [==============================] - 0s 317us/step - loss: 0.0743 - accuracy: 0.9760 - val_loss: 0.0627 - val_accuracy: 0.9920
# Epoch 172/250
# 750/750 [==============================] - 0s 292us/step - loss: 0.0732 - accuracy: 0.9733 - val_loss: 0.0617 - val_accuracy: 0.9920
# Epoch 173/250
# 750/750 [==============================] - 0s 304us/step - loss: 0.0721 - accuracy: 0.9773 - val_loss: 0.0606 - val_accuracy: 0.9920
# Epoch 174/250
# 750/750 [==============================] - 0s 202us/step - loss: 0.0710 - accuracy: 0.9773 - val_loss: 0.0597 - val_accuracy: 0.9920
# Epoch 175/250
# 750/750 [==============================] - 0s 386us/step - loss: 0.0699 - accuracy: 0.9773 - val_loss: 0.0587 - val_accuracy: 0.9920
# Epoch 176/250
# 750/750 [==============================] - 0s 310us/step - loss: 0.0688 - accuracy: 0.9773 - val_loss: 0.0576 - val_accuracy: 0.9920
# Epoch 177/250
# 750/750 [==============================] - 0s 317us/step - loss: 0.0677 - accuracy: 0.9787 - val_loss: 0.0567 - val_accuracy: 0.9920
# Epoch 178/250
# 750/750 [==============================] - 0s 279us/step - loss: 0.0667 - accuracy: 0.9787 - val_loss: 0.0559 - val_accuracy: 0.9920
# Epoch 179/250
# 750/750 [==============================] - 0s 375us/step - loss: 0.0659 - accuracy: 0.9787 - val_loss: 0.0548 - val_accuracy: 0.9920
# Epoch 180/250
# 750/750 [==============================] - 0s 433us/step - loss: 0.0645 - accuracy: 0.9813 - val_loss: 0.0539 - val_accuracy: 0.9920
# Epoch 181/250
# 750/750 [==============================] - 0s 319us/step - loss: 0.0636 - accuracy: 0.9813 - val_loss: 0.0530 - val_accuracy: 0.9960
# Epoch 182/250
# 750/750 [==============================] - 0s 441us/step - loss: 0.0628 - accuracy: 0.9813 - val_loss: 0.0523 - val_accuracy: 0.9960
# Epoch 183/250
# 750/750 [==============================] - 0s 379us/step - loss: 0.0618 - accuracy: 0.9813 - val_loss: 0.0515 - val_accuracy: 0.9960
# Epoch 184/250
# 750/750 [==============================] - 0s 328us/step - loss: 0.0611 - accuracy: 0.9827 - val_loss: 0.0508 - val_accuracy: 0.9960
# Epoch 185/250
# 750/750 [==============================] - 0s 279us/step - loss: 0.0602 - accuracy: 0.9840 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 186/250
# 750/750 [==============================] - 0s 359us/step - loss: 0.0591 - accuracy: 0.9840 - val_loss: 0.0492 - val_accuracy: 0.9960
# Epoch 187/250
# 750/750 [==============================] - 0s 299us/step - loss: 0.0581 - accuracy: 0.9853 - val_loss: 0.0485 - val_accuracy: 0.9960
# Epoch 188/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.0575 - accuracy: 0.9853 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 189/250
# 750/750 [==============================] - 0s 352us/step - loss: 0.0566 - accuracy: 0.9853 - val_loss: 0.0469 - val_accuracy: 1.0000
# Epoch 190/250
# 750/750 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.98 - 0s 343us/step - loss: 0.0553 - accuracy: 0.9867 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 191/250
# 750/750 [==============================] - 0s 297us/step - loss: 0.0544 - accuracy: 0.9893 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 192/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.0535 - accuracy: 0.9893 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 193/250
# 750/750 [==============================] - 0s 256us/step - loss: 0.0525 - accuracy: 0.9907 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 194/250
# 750/750 [==============================] - 0s 255us/step - loss: 0.0517 - accuracy: 0.9907 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 195/250
# 750/750 [==============================] - 0s 301us/step - loss: 0.0509 - accuracy: 0.9893 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 196/250
# 750/750 [==============================] - 0s 243us/step - loss: 0.0501 - accuracy: 0.9920 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 197/250
# 750/750 [==============================] - 0s 239us/step - loss: 0.0494 - accuracy: 0.9933 - val_loss: 0.0409 - val_accuracy: 1.0000
# Epoch 198/250
# 750/750 [==============================] - 0s 241us/step - loss: 0.0485 - accuracy: 0.9933 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 199/250
# 750/750 [==============================] - 0s 247us/step - loss: 0.0477 - accuracy: 0.9933 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 200/250
# 750/750 [==============================] - 0s 490us/step - loss: 0.0467 - accuracy: 0.9947 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 201/250
# 750/750 [==============================] - 0s 330us/step - loss: 0.0459 - accuracy: 0.9960 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 202/250
# 750/750 [==============================] - 0s 276us/step - loss: 0.0452 - accuracy: 0.9973 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 203/250
# 750/750 [==============================] - 0s 286us/step - loss: 0.0444 - accuracy: 0.9960 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 204/250
# 750/750 [==============================] - 0s 314us/step - loss: 0.0438 - accuracy: 0.9960 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 205/250
# 750/750 [==============================] - 0s 244us/step - loss: 0.0432 - accuracy: 0.9947 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 206/250
# 750/750 [==============================] - 0s 336us/step - loss: 0.0422 - accuracy: 0.9973 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 207/250
# 750/750 [==============================] - 0s 314us/step - loss: 0.0414 - accuracy: 0.9987 - val_loss: 0.0342 - val_accuracy: 1.0000
# Epoch 208/250
# 750/750 [==============================] - 0s 350us/step - loss: 0.0408 - accuracy: 0.9987 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 209/250
# 750/750 [==============================] - 0s 295us/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 210/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 1.0000
# Epoch 211/250
# 750/750 [==============================] - 0s 262us/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 212/250
# 750/750 [==============================] - 0s 393us/step - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 213/250
# 750/750 [==============================] - 0s 269us/step - loss: 0.0377 - accuracy: 0.9987 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 214/250
# 750/750 [==============================] - 0s 356us/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 215/250
# 750/750 [==============================] - 0s 298us/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 216/250
# 750/750 [==============================] - 0s 362us/step - loss: 0.0360 - accuracy: 0.9987 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 217/250
# 750/750 [==============================] - 0s 311us/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 1.0000
# Epoch 218/250
# 750/750 [==============================] - 0s 382us/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 219/250
# 750/750 [==============================] - 0s 235us/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 220/250
# 750/750 [==============================] - 0s 241us/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 221/250
# 750/750 [==============================] - 0s 246us/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 222/250
# 750/750 [==============================] - 0s 328us/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 223/250
# 750/750 [==============================] - 0s 381us/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 224/250
# 750/750 [==============================] - 0s 309us/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 225/250
# 750/750 [==============================] - 0s 277us/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 1.0000
# Epoch 226/250
# 750/750 [==============================] - 0s 230us/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 227/250
# 750/750 [==============================] - 0s 261us/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 228/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 229/250
# 750/750 [==============================] - 0s 327us/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 230/250
# 750/750 [==============================] - 0s 272us/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 231/250
# 750/750 [==============================] - 0s 290us/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 232/250
# 750/750 [==============================] - 0s 224us/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 233/250
# 750/750 [==============================] - 0s 254us/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 234/250
# 750/750 [==============================] - 0s 287us/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 235/250
# 750/750 [==============================] - 0s 326us/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 236/250
# 750/750 [==============================] - 0s 224us/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 237/250
# 750/750 [==============================] - 0s 178us/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 238/250
# 750/750 [==============================] - 0s 211us/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 239/250
# 750/750 [==============================] - 0s 220us/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 240/250
# 750/750 [==============================] - 0s 257us/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 241/250
# 750/750 [==============================] - 0s 243us/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 242/250
# 750/750 [==============================] - 0s 304us/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 243/250
# 750/750 [==============================] - 0s 294us/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 244/250
# 750/750 [==============================] - 0s 247us/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 245/250
# 750/750 [==============================] - 0s 273us/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 246/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 247/250
# 750/750 [==============================] - 0s 312us/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 248/250
# 750/750 [==============================] - 0s 226us/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 249/250
# 750/750 [==============================] - 0s 288us/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 250/250
# 750/750 [==============================] - 0s 321us/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %% [markdown]
# Notar que se agregaron una keys, asociadas al set de validación. Grafiquemos.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ¿Cuántos parámetros tiene ahora el modelo?

# %%
print(model.get_weights())
# Out:
# [array([[-2.6366632 ,  0.67541796, -1.930901  ,  1.5568584 ],
#        [-0.33857095,  1.8146925 , -1.2759173 , -0.07224238]],
#       dtype=float32), array([-1.3939797 , -0.17193663,  0.73996925, -0.90899223], dtype=float32), array([[-5.594674 ],
#        [-2.6571968],
#        [ 3.3147964],
#        [ 5.4340653]], dtype=float32), array([-1.6200417], dtype=float32)]

# %% [markdown]
# Y graficamos las fronteras de decisión. ¿Notan que ya no es una frontera abrupta, sino que hay una zona de cambio?¿A qué se debe?

# %%
plt.figure(figsize = (10,6))

ax = sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, levels = 10, alpha=0.3, cmap = 'plasma')
plt.show()

# %% [markdown]
# **Ejercicio:** volver a correr esta sección, pero reemplazando la función que genera los datos `make_blobs` por `make_moons`. ¿Qué problema ven en el resultado?¿Y si hacen lo mismo para `make_circles?`
#
# **Ejercicio**: con los datos producidos por `make_moons`, agregar una capa a la red neuronal, con 10 neuronas y función de activación `relu`.
#
# **Ejercicio**: repetir el ejercicio anterior, pero para los datos producidos por `make_circles`.

# %% [markdown]
# ## 2. MNIST
#
# El dataset de MNIST es un dataset muy conocido. Consiste en dígitos escritos a mano. Muchas modelos de redes neuronales son probados primeros en este set. Pueden encontrar una descripción más detallada, y un ranking de modelos con su desempeño, en el siguiente link.
#
# https://en.wikipedia.org/wiki/MNIST_database
#
# Vamos a arrancar con una sola capa, con una activación `softmax`, ya que se trata de diez clases.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import random
from sklearn.model_selection import train_test_split
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import keras

# %% [markdown]
# **1. Carga de datos**
#
# Cada instancia del dataset es una imagen guardada en una carpeta con la etiqueta correspondiente.

# %%
directorio = 'MNIST/'

# %% [markdown]
# Miramos las carpetas que hay adentro de la carpeta MNIST

# %%
print(os.listdir(directorio))

# %% [markdown]
# Creamos los contenedores vacíos

# %%
todas_imagenes = []
y_todas_imagenes = []

# %% [markdown]
# y los llenamos.

# %%
digitos = np.arange(0,10)
for digito in digitos:
    directorio = 'MNIST/' + str(digito) + '/'
    print(digito, directorio)
    print('Hay', len(os.listdir(directorio)),'imagenes')
    for imagen in os.listdir(directorio):
        todas_imagenes.append(plt.imread(directorio + imagen))
        y_todas_imagenes.append(digito)
        
todas_imagenes = np.array(todas_imagenes)
y_todas_imagenes = np.array(y_todas_imagenes)

# %% [markdown]
# **2. Preprocesado**
#
# **Ejercicio:** Mirar el `shape` de `X` y responder: ¿Cuántas instancias son?¿Qué ancho y largo tienen las imágenes?¿Cuántas bandas?

# %%
print(todas_imagenes.shape, y_todas_imagenes.shape)
n_instancias = todas_imagenes.shape[COMPLETAR]
ancho_imagen = todas_imagenes.shape[COMPLETAR]
largo_imagen = todas_imagenes.shape[COMPLETAR]

# %% [markdown]
# Miramos una imagen al azar.

# %%
idx_imagen = np.random.randint(0,todas_imagenes.shape[0])
plt.figure(figsize = (6,6))
plt.title('Es un ' + str(y_todas_imagenes[idx_imagen]))
plt.imshow(todas_imagenes[idx_imagen, :, :])
plt.show()

# %% [markdown]
# **Ejercicio:** Crear un arreglo `X` que sea igual a `todas_imagenes`, pero de forma `(n_instancias, largo_imagen * ancho_imagen)`.

# %%
X = todas_imagenes.reshape(COMPLETAR, COMPLETAR*COMPLETAR)
print(X.shape)

# %% [markdown]
# **Ejercicio:** Reescalar las imágenes entre 0 y 1.

# %%
X = X/COMPLETAR

# %% [markdown]
# **Ejercicio:** usar el `to_categorical` de Keras para llevar `y_todas_imagenes` a una columna con unos y ceros para cada clase `y` (One Hot Encoding).

# %%
from keras.utils import to_categorical
y = to_categorical(COMPLETAR)
print(y.shape)

# %% [markdown]
# **Ejercicio:** hacer un `train_test_split`. Usar el 20% del dataset como conjunto de test. Fijar el random state en 42.

# %%
X_train, X_test, y_train, y_test = COMPLETAR

# %% [markdown]
# **3. Entrenamiento del modelo**
#
# Comenzar entrenando un Red Neuronal de una capa, con diez neuronas, función de activación `softmax` y pérdida `categorical_crossentropy`. Usar como optimizador `Adam` y `epoch = 20`.

# %%
from keras.models import Sequential
from keras.layers import Dense
import keras

model = COMPLETAR
model.add(COMPLETAR)

optimizador = keras.optimizers.Adam(COMPLETAR)

model.compile(optimizer=COMLPETAR,loss=COMPLETAR,
              metrics=['accuracy'])

history = model.fit(COMPLETAR, COMPLETAR, COMPLETAR, validation_split=0.1)

# %% [markdown]
# **Ejercicio:** ¿cuántos parámetros tiene el modelo? Recordar que hay una función de Keras que hace un *informe* de la red neuronal.

# %%
model.COMPLETAR()

# %% [markdown]
# **Ejercicio:** Graficar la pérdida y la exactitud en función de *epochs* para validación y entrenamiento.
#
# https://keras.io/visualization/

# %%
COMPLETAR

# %% [markdown]
# **4. Evaluación de los resultados.**
#
# **Ejercicio**: predecir las etiquetas de todo el set de testeo.

# %%
y_test_pred = model.COMPLETAR(COMPLETAR)

# %% [markdown]
# Esto sirve para pasar de probabilidades a la etiqueta en sí. En este caso, la etiqueta es el dígito, y corresponde al número de columna.

# %%
y_test_pred = np.argmax(y_test_pred, axis = 1)
y_test_pred.shape

# %% [markdown]
# **Ejercicio:** Calcular exactitud y la matriz de confusión para el conjunto de entrenamiento.

# %%
from sklearn.metrics import confusion_matrix

y_test = np.argmax(y_test,axis = 1)

COMPLETAR(COMPLETAR, COMPLETAR)

# %%
from sklearn.metrics import accuracy_score

COMPLETAR

# %% [markdown]
# **Ejercicio:** ¿Dónde se está confundiendo? Graficar algunos ejemplos.

# %%
errores = COMPLETAR != COMPLETAR

# %%
imagenes_errores = X_test[COMPLETAR,:]
y_test_errores = y_test[COMPLETAR]
y_test_pred_errores = y_test_pred[COMPLETAR]
print(imagenes_errores.shape)

# %%
imagenes_errores = imagenes_errores.reshape(imagenes_errores.shape[0], ancho_imagen, largo_imagen)
print(imagenes_errores.shape)

# %%
idx_imagen = np.random.randint(0,imagenes_errores.shape[0])
plt.figure(figsize = (6,6))
plt.title('Es un ' + str(y_test_errores[idx_imagen]) +'. Fue etiquetado como ' + str(y_test_pred_errores[idx_imagen]))
plt.imshow(imagenes_errores[idx_imagen, :, :])
plt.show()

# %% [markdown]
# **Ejercicio:** Volver a entrenar, pero agregando una capa con 800 neuronas y función de activación `relu`.
