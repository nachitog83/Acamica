# %%
from lib_acamica import lib_acamica as lica
# Out:
# <img src='data:image/jpeg;base64,...'>
#  SYSTEM:   Windows
#  VERSION:   10.0.18362
#  MACHINE:   AMD64
#  PROCESSOR:   Intel64 Family 6 Model 142 Stepping 11, GenuineIntel
#  VERSION PYTHON:   3.7.3
#  COMPILER:   MSC v.1915 64 bit (AMD64)
#  ALIASED:   Windows-10-10.0.18362-SP0
#  TERSE:   Windows-10
#  INTERPRETER:   ('64bit', 'WindowsPE')
# <img src='data:image/png;base64,...'>

# %%
help(lica.detalle)
# Out:
# Help on function detalle in module lib_acamica.lib_acamica:
#
# detalle()
#     Funciones que tiene la libreria:
#         .
#         - librerias()
#         - porc_null_col()
#         - Cat_plot_basic()
#         - heat()
#         .

# %%
help(lica.librerias)
# Out:
# Help on function librerias in module lib_acamica.lib_acamica:
#
# librerias()
#     Funcion para importar librerias.
#     Dicha funcion cuenta con las siguientes librerias:
#         - pandas as pd
#         - numpy as np
#         - seaborn as sns
#         - matplotlib.pyplot as plt
#     Importar las librerias de la siguiente forma:
#         - pd, np, sns, plt =  lica.librerias()

# %%
pd, np, sns, plt =  lica.librerias()
# Out:
# Se importaron las siguientes librerias:
#  - pandas as pd
#  - numpy as np
#  - seaborn as sns
#  - matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris.csv')

# %%
titanic = pd.read_csv('titanic.csv')

# %%
iris.head(1)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
help(lica.porc_null_col)
# Out:
# Help on function porc_null_col in module lib_acamica.lib_acamica:
#
# porc_null_col(pd, df)
#     Funcion para mostrar el porcentaje de nulos que tienen las columnas
#     Llamarla de la siguiente forma:
#         - lica.porc_null_col(pd, nombre_de_tu_df)

# %%
lica.porc_null_col(pd, iris)
# Out:
#        columnas  total_registros_fila  total_columns  %_nulos
# 0  sepal.length                   150              0      0.0
# 1   sepal.width                   150              0      0.0
# 2  petal.length                   150              0      0.0
# 3   petal.width                   150              0      0.0
# 4       variety                   150              0      0.0

# %%
lica.porc_null_col(pd, titanic)
# Out:
#        columnas  total_registros_fila  total_columns  %_nulos
# 10        Cabin                   891            687    77.10
# 5           Age                   891            177    19.87
# 11     Embarked                   891              2     0.22
# 0   PassengerId                   891              0     0.00
# 1      Survived                   891              0     0.00
# 2        Pclass                   891              0     0.00
# 3          Name                   891              0     0.00
# 4           Sex                   891              0     0.00
# 6         SibSp                   891              0     0.00
# 7         Parch                   891              0     0.00
# 8        Ticket                   891              0     0.00
# 9          Fare                   891              0     0.00

# %%
help(lica.Cat_plot_basic)
# Out:
# Help on function Cat_plot_basic in module lib_acamica.lib_acamica:
#
# Cat_plot_basic(plt, df, colUno, colDos)
#     Función para graficar un catplot simple
#     - lica.Cat_plot_basic(plt, nombre_de_tu_df, colUno, colDos)

# %%
lica.Cat_plot_basic(plt, iris, 'variety', 'petal.width')

# %%
lica.Cat_plot_basic(plt, titanic, 'Pclass', 'SibSp')

# %%
help(lica.heat)
# Out:
# Help on function heat in module lib_acamica.lib_acamica:
#
# heat(plt, sns, pd, df)
#     Funcion para mostrar el porcentaje de nulos que tienen las columnas
#     Llamarla de la siguiente forma:
#         - lica.heat(plt, sns, pd, nombre_del_df)

# %%
lica.heat(plt, sns, pd, iris)
# Out:
# Se descartan las siguientes columnas porque son categoricas:
# variety

# %%
lica.heat(plt, sns, pd, titanic)
# Out:
# Se descartan las siguientes columnas porque son categoricas:
# Name Sex Ticket Cabin Embarked
